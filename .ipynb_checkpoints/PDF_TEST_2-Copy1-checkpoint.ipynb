# %%
def bank_stament_read(file_name,bank_name):
    import numpy as np                        # Numerical Python package
    import tabula                             # PDF table extra package
    import numpy as np
    import pandas as pd
    import os
    import re,string
    import operator as op
    import sys
    import tabula
    from dateutil.parser import parse # Fixing the dates
    if not sys.warnoptions:
        import warnings
        warnings.simplefilter("ignore")
    
    pdf_file = file_name
    pd.set_option('display.max_rows',None)
    pd.set_option('display.max_columns',None)
    df = tabula.read_pdf(pdf_file, pages = 'all',multiple_tables=True)
    df_list=df
    col_list=["Description","Narration","Remarks","Particulars","DESCRIPTION","Description","Description","PARTICULARS",
                  "Transaction Details","Narration","NARRATION","PERTICULERS","Details of transaction","ransaction Remarks",
                 "Transaction\rParticulars","Transaction Description","ransaction Remarks","Account Description","NARATION",
                 "Narration Chq/Ref No","Deposits","Amount (Rs.)","Credit","CREDIT","Deposit Amt.","DEPOSIT","Deposit",
          "Deposit Amount\r(INR )","Amount","Deposit Amt","Type","Deposit Balance","WithDrawal","Value",
              "Credit (Rs.)","Withdrawal Amt. Deposit Amt.","Deposit Amount\r(INR )","Credit(Rs)","Withdrawals Deposits",
               "Cr Amount","Withdrawal (Dr)/","Withdrawal Amt.","Withdrawal","Withdrawal","DEBIT","Withdrawals","Debit",
          "Withdrawal (Dr)" ,"Withdrawal Amt. Deposit Amt.","Withdrawal (Dr)/","Withdrawal Amount\r(INR )","Debit (Rs.)",
          "Debit(Rs)","WITHDRAWALS","Withdrawal INR","Withdrawal Amt","Amount","Withdrawal Amount","Withdrawals Deposits",
             "Dr Amount", "Balance","Closing Balance","BALANCE","Running Balance","BALANCE","Balance (INR )","Amount","MODE**",
                "Running","Balance(Rs)","Total Amount\rDr/Cr","Date","date","Transaction","Txn","Transaction Date","Debit/Credit",
          "Transaction date", "Txn Date", "Tran Date","Balance (?)","Branch","Cheque No","Chq./Ref.","Entry Date",'Cheque',
             "TRANSACTION\rDATE","Trans Date","Tran Date","DATE","Post Date","Value\rDate","Date (Value\rDate)","Tran Date",
             "Txn dt", "Txn Dt","Value Date" ,'Chq./Ref.No.','Value Dt',"Chq\rNo.","Transaction Description","Total Amount\rDr/Cr",
          "Debit (Rs.)","Credit (Rs.)","Balance (Rs.)","Dr Amount","Cr Amount","Instruments","Total Amou"]

    date_list = ["Date","date","Transaction","Txn","Transaction Date","Transaction date", "Txn Date", "Tran Date","Date",
             "TRANSACTION\rDATE","Trans Date","Tran Date","DATE","Post Date","Value\rDate","Date (Value\rDate)",
             "Txn dt", "Txn Dt","Value Date"]
    
    narration_list = ["Description","Narration","Remarks","Particulars","DESCRIPTION","Description","Description","PARTICULARS",
                  "Transaction Details","Narration","NARRATION","PERTICULERS","Details of transaction","ransaction Remarks",
                 "Transaction\rParticulars","Transaction Description","ransaction Remarks","Account Description","NARATION",
                 "Narration Chq/Ref No"]

    credit_list = ["Deposits","Amount (Rs.)","Credit","CREDIT","Deposit Amt.","DEPOSIT","Deposit","Deposit Amount\r(INR )","Amount",
              "Credit (Rs.)","Withdrawal Amt. Deposit Amt.","Deposit Amount\r(INR )","Credit(Rs)","Withdrawals Deposits",
               "Cr Amount","Withdrawal (Dr)/","DEPOSITS","WITHDRAWALS"]

    debit_list = ["Withdrawal Amt.","Withdrawal","Withdrawal","DEBIT","Withdrawals","Debit","Withdrawal (Dr)"
              ,"Withdrawal Amt. Deposit Amt.","Withdrawal (Dr)/","Withdrawal Amount\r(INR )","Debit (Rs.)","Debit(Rs)",
             "WITHDRAWALS","Withdrawal INR","Withdrawal Amt","Amount","Withdrawal Amount","Withdrawals Deposits","WithDrawal",
             "Dr Amount"]


    balance_list = ["Balance","Closing Balance","BALANCE","Running Balance","BALANCE","Balance (INR )","Amount",
                "Running","Balance(Rs)","Total Amount\rDr/Cr"]

    test_data=df_list[0]
    col_len=test_data.shape[1]
    tab_cols=test_data.columns
    table_columns=[]
    row_index=[]
    for elem in range(len(tab_cols)):
        if tab_cols[elem] in col_list:
            col_name=tab_cols[elem]
            table_columns.append(col_name)
        else:
            table_columns.append("Unknown_column")
    uc_count=op.countOf(table_columns, "Unknown_column")
    if uc_count>=3 or len(table_columns)<=3:
        for row_ind in range(col_len-1):
            test_list=list(test_data[tab_cols[row_ind]])
            for i in range(len(col_list)):
                col_el=col_list[i]
                if col_el in test_list:
                    row_inde=test_list.index(col_el)
                    row_index.append(row_inde)
        if len(row_index)==0:
            if len(df_list)<= 4:
                lst_no=0
            else:
                lst_no=4
            data1=df_list[1]
            data2=df_list[2]
            data3=df_list[lst_no]
            data1_columns=[]
            data2_columns=[]
            data3_columns=[]
            page_data1=data1.values.tolist()
            page_data2=data2.values.tolist()
            page_data3=data3.values.tolist()
            data1_cols=data1.columns
            data2_cols=data2.columns
            data3_cols=data3.columns
            for elem in range(len(data1_cols)):
                if data1_cols[elem] in col_list:
                    col_name=data1_cols[elem]
                    data1_columns.append(col_name)
                else:
                    data1_columns.append("Unknown_column")
            for elem in range(len(data2_cols)):
                if data2_cols[elem] in col_list:
                    col_name=data2_cols[elem]
                    data2_columns.append(col_name)
                else:
                    data1_columns.append("Unknown_column")
            for elem in range(len(data3_cols)):
                if data3_cols[elem] in col_list:
                    col_name=data3_cols[elem]
                    data3_columns.append(col_name)
                else:
                    data3_columns.append("Unknown_column")            
            
            data1_count=op.countOf(data1_columns, "Unknown_column")
            data2_count=op.countOf(data2_columns, "Unknown_column")
            data3_count=op.countOf(data3_columns, "Unknown_column")
            data_uc_count=[data1_count,data2_count,data3_count]
            min_uc_index = data_uc_count.index(min(data_uc_count))
            dict_cols={0:data1_columns,1:data2_columns,2:data3_columns}
            dict_data={0:data1,1:data2,2:data3}
            data_tab_cols=dict_cols[min_uc_index]
            data_first=dict_data[min_uc_index]
            pdf_data=[]
            page_data0=data_first.values.tolist()
            pdf_data=pdf_data + page_data0
            pdf_data=pdf_data + page_data1
            pdf_data=pdf_data + page_data2
            pdf_data=pdf_data + page_data3
            
            for ls in range(len(df_list)):
                page_data=df[ls].values.tolist()
                pdf_data=pdf_data+page_data
            data1_pdf=pd.DataFrame(pdf_data)
            repete=data1_pdf.shape[1]-len(data_tab_cols)
            
            for add in range(repete):
                data_tab_cols.append('column_added')
            pdf_data=pd.DataFrame(pdf_data,columns= data_tab_cols)
            data_pdf=pdf_data.replace(np.nan,'')
            com_table=data_pdf
            com_table1=data_pdf
        
        elif min(row_index)>=2:
            test_data1=test_data.values.tolist()
            row_value=min(row_index)
            data1_col_list=test_data1[row_value]
            data2_col_list=test_data1[row_value+1]
            data_col_list=data1_col_list + data2_col_list
            columns_list=[]
            row_columns=[]
            
            for elem in range(len(data_col_list)):
                txt=data_col_list[elem]
                txt=str(txt)
                list_txt =list(txt.split())
                columns_list=columns_list+list_txt
            for elem in range(len(columns_list)):
                if columns_list[elem] in col_list:
                    col_name=columns_list[elem]
                    row_columns.append(col_name)
            data1=df_list[1]
            data1=data1.values.tolist()
            #data1=pd.DataFrame(data1,columns=row_columns)
            for lst_len in range(len(df_list)):
                page_data=df_list[lst_len]
                page_data=page_data.values.tolist()
                data1=data1+page_data
            pdf_data1=pd.DataFrame(data1)    
            repete=pdf_data1.shape[1]-len(row_columns)
            for add in range(repete):
                row_columns.append('column_added')
            pdf_data=pd.DataFrame(data1,columns=row_columns)
            pdf_data=pdf_data.replace(np.nan,'')
            com_table=pdf_data
            com_table1=pdf_data
        else:
            num_row=0
            pdf_data=[]
            pdf_data.append(list(df[num_row]))
            pdf_columns=list(df[num_row])
            for ls in range(len(df_list)-num_row):
                page_data=df[ls+num_row].values.tolist()
                pdf_data=pdf_data+page_data
            data_pdf=pd.DataFrame(pdf_data)
            data_pdf=data_pdf.replace(np.nan,'')
            repete=data_pdf.shape[1]-len(pdf_columns)
            for add in range(repete):
                pdf_columns.append('columns')
        
            data_pdf=data_pdf.rename(columns=data_pdf.iloc[0]).drop(data_pdf.index[0]) 
            data_pdf1=data_pdf.rename(columns=data_pdf.iloc[0]).drop(data_pdf.index[0])
            com_table=data_pdf
            com_table1=data_pdf1    
    else:
        num_row=0
        pdf_data=[]
        pdf_data.append(list(df[num_row]))
        pdf_columns=list(df[num_row])
        for ls in range(len(df_list)-num_row):
            page_data=df[ls+num_row].values.tolist()
            pdf_data=pdf_data+page_data
        data_pdf=pd.DataFrame(pdf_data)
        data_pdf=data_pdf.replace(np.nan,'')
        repete=data_pdf.shape[1]-len(pdf_columns)
        for add in range(repete):
            pdf_columns.append('columns')
        
        data_pdf=data_pdf.rename(columns=data_pdf.iloc[0]).drop(data_pdf.index[0]) 
        data_pdf1=data_pdf.rename(columns=data_pdf.iloc[0]).drop(data_pdf.index[0])
        com_table=data_pdf
        com_table1=data_pdf1
    cols = list(com_table.columns)
    cols1 = list(com_table1.columns)
    #cols2 = list(com_table2.columns)
    for i in range(len(cols)):
        if cols[i] in date_list:
            date=cols[i]
            date_ind=i
    for j in range(len(cols1)):
        if cols1[j] in date_list:
            date=cols1[j]
            date_ind=j
    for k in range(len(cols)):
        if cols[k] in narration_list:
            narration=cols[k]
            nar_ind=k
    for l in range(len(cols1)):
        if cols1[l] in narration_list:
            narration=cols1[l]
            nar_ind=l
    for m in range(len(cols)):
        if cols[m] in credit_list:
            credit=cols[m]
            credit_ind=m 
    for n in range(len(cols1)):
        if cols1[n] in credit_list:
            credit=cols1[n]
            credit_ind=n 
    for dbt in range(len(cols)):
        if cols[dbt] in debit_list:
            debit=cols[dbt]
            debit_ind=dbt
    for dbt1 in range(len(cols1)):
        if cols1[dbt1] in debit_list:
            debit=cols1[dbt1]
            debit_ind=dbt1
    for blns in range(len(cols)):
        if cols[blns] in balance_list:
            balance=cols[blns]
            balance_ind=blns
    for blns1 in range(len(cols1)):
        if cols1[blns1] in balance_list:
            balance=cols1[blns1]
            balance_ind=blns1
    Transaction_date =list(com_table[cols[date_ind]])
    Narration = list(com_table[cols[nar_ind]])
    Deposits=list(com_table[cols[credit_ind]])
    Debit = list(com_table[cols[debit_ind]])
    Balance = list(com_table[cols[balance_ind]])
    data4=pd.DataFrame(Transaction_date,columns=["Transaction Date"])
    data5 = pd.DataFrame(Narration,columns=["Narration"])
    data6 = pd.DataFrame(Deposits,columns=["Credit"])
    data7 = pd.DataFrame(Debit,columns=["Debit"])
    data8 = pd.DataFrame(Balance, columns= ["Balance"])
    data=data4.join(data5)
    data=data.join(data6)
    data=data.join(data7)
    data =data.join(data8)
    data=data.replace(np.nan,'')
    axis_list=["axis-bank","Axis Bank  India","Axis Bank  India","AXIS (UTI) Bank","Axis Bank India","Axis Bank, India",
                   "Axis Ban","Axis Bank","Axis Bank Ltd","Axis Bank Ltd.","Axis Bank ","Axis","axis","AXIS"]

    if bank_name in axis_list:
        for ele in range(len(Narration)-1):
            if Transaction_date[ele] == '' and Balance [ele]== '':
                Narration[ele+1]=str(Narration[ele])+str(Narration[ele+1])
    else:
        for ele in range(len(Narration)):
            if Transaction_date[ele] == '':
                Narration[ele-1]=str(Narration[ele-1])+str(Narration[ele])
    
    Transaction_date=pd.DataFrame(Transaction_date,columns=["Transaction Date"])
    Narration= pd.DataFrame(Narration,columns=["Narration"])
    Deposits = pd.DataFrame(Deposits,columns=["Credit"])
    Debit = pd.DataFrame(Debit,columns=["Debit"])
    Balance = pd.DataFrame(Balance,columns=["Balance"])
    data=Transaction_date.join(Narration)
    data=data.join(Deposits)
    data=data.join(Debit)
    data=data.join(Balance)
    #data=data.replace('',np.nan)
    #data=data.dropna()
    txn_date = list(data["Transaction Date"])
    cr_list=list(data["Credit"])
    dr_list=list(data["Debit"])
    bls_list=list(data["Balance"])
    row_index=[]
    for row_num in range(len(data["Narration"])):
        if txn_date[row_num]== '':
            a=row_num
            row_index.append(a)
        elif cr_list[row_num]== '' and dr_list[row_num]== '' and bls_list=='' :
            b=row_num
            row_index.append(b)
    unique_row_index = []
    for x in range(len(row_index)):
        if row_index[x] not in unique_row_index:
            row_ind=row_index[x]
            unique_row_index.append(row_ind)
    data=data.drop(unique_row_index,axis=0)
    salary1 = data[data["Narration"].str.contains("SALARY")]
    salary2 = data[data["Narration"].str.contains("Salary")]
    sala_cr= data[data["Narration"].str.contains("CREDIT")]
    salary3 = data[data["Narration"].str.contains("salary")]
    sal_ac = data[data["Narration"].str.contains("SAL")]
    sal_fl = data[data["Narration"].str.contains("Sal")]
    #sal_al = data[data["Narration"].str.contains("sal")]
    NEFT = data[data["Narration"].str.contains("NEFT")]
    IMPS = data[data["Narration"].str.contains("IMPS")]
    sal=sal_ac.append(sal_fl)
    #sal = sal.append(sal_al)
    salary=salary1.append(salary2)
    salary=salary.append(salary3)
    salary=salary.append(sal)
    salary=salary.drop_duplicates(subset="Narration")
    #dataframe.drop_duplicates(subset, keep, inplace, ignore_index)
    UPI = data[data["Narration"].str.contains("UPI")]
    NACH = data[data["Narration"].str.contains("NACH")]
    ACH = data[data["Narration"].str.contains("ACH")]
    NACH=NACH.append(ACH)
    
    ecs=["ECSRTN","ECSRTNCHGS","NACH_AD,RTN_CHRG","ACH DEBIT RETURN CHARGES","EMI RTN CHARGES","NACH RTN CHG","Chrg:Ecs Return",
    "Chrg:Ecs Mandate","ECS DR RTN","NACH RETURN CHARGES","ECS Return","Bounce Charges","ACH RTN","Debit Return Charges","NACH Return",
    "RTN Charges","ECS/ACH RETURN","ACH D","ACH RETURN","ACH DEBIT RETURN"]
    
    fantasy_gaming=["Rummy","rummy","Junglee","junglee","Mpl","mpl","Dream11","dream11","Adda52","adda52","Ace2three","ace2three",
                   "Poker","poker","Rummy Circle","Pokerbaazi","pokerbaazi","Ace2Three","My11Circle"]
    
    ecs_rtn = data[data["Narration"].str.contains("ECSRTN")]
    ecs_col=list(ecs_rtn.columns)
    ecs_rtn_data=ecs_rtn.values.tolist()
    for es in range(len(ecs)):
        ecs_name=ecs[es]
        ecs1 = data[data["Narration"].str.contains(ecs_name)]
        ecs1_data = ecs1.values.tolist()
        ecs_list =ecs_rtn_data + ecs1_data
    ecs_tab=pd.DataFrame(ecs_list,columns=ecs_col)
    gaming = data[data["Narration"].str.contains("ummy")]
    gm_col=list(gaming.columns)
    gm_rtn_data=gaming.values.tolist()
    for es in range(len(fantasy_gaming)):
        gm_name=fantasy_gaming[es]
        gm1 = data[data["Narration"].str.contains(gm_name)]
        gm1_data = gm1.values.tolist()
        gm_list =gm_rtn_data + gm1_data
    gm_tab=pd.DataFrame(gm_list,columns=gm_col)    
    data_frame=data.to_json()
    print(data)
    upi_json=UPI.to_json()
    return (data_frame,upi_json)
bank_name = "icici_bank"
file_name= 'C:/Users/VSK/Desktop/Bank_Statement/Bank statement/APP1671313131413878.pdf'
bank_stament_read(file_name,bank_name)
# Out:
# Got stderr: Oct 11, 2022 10:44:08 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (9) in font Helvetica
#     Transaction Date                                          Narration  \
# 0         1 Jun 2020              BY TRANSFER-Transfer to\rown account-
# 1         1 Jun 2020                TO TRANSFER-INB ASTHA\rCOMMODITIES-
# 2         1 Jun 2020  BY TRANSFER-INB\rIMPS015316697383/00000000\r00...
# 3         1 Jun 2020  BY TRANSFER-\rUPI/CR/015319322270/Razorp\ray/I...
# 4         2 Jun 2020       DEBIT-CMP MANDATE DEBIT\rBajaj Finance Ltd.-
# 5         2 Jun 2020  BY TRANSFER-INB\rIMPS015418333478/98339440\r01...
# 6         4 Jun 2020                              TO TRANSFER-Transfer-
# 7         4 Jun 2020  BY TRANSFER-\rUPI/CR/015615324250/PRATH\rAME/I...
# 8         5 Jun 2020          DEBIT-CMP MANDATE DEBIT\rIVL FINANCE LTD-
# 9         5 Jun 2020        DEBIT-ACHDr\rCITI00002000000037\rBDDMINBFC-
# 10        5 Jun 2020  TO TRANSFER-INB\rIMPS/P2A/015719806632/XXX\rXX...
# 11        6 Jun 2020  TO TRANSFER-\rUPI/DR/015813769589/Airtel\rH/UT...
# 12        8 Jun 2020  BY TRANSFER-INB\rIMPS016022010235/73311543\r59...
# 13        8 Jun 2020  TO TRANSFER-\rUPI/DR/016022305159/ASTHA\rCR/HD...
# 14        8 Jun 2020  TO TRANSFER-\rUPI/DR/016022308436/ASTHA\rCR/HD...
# 15        9 Jun 2020                              TO TRANSFER-Transfer-
# 16      15 Jun\r2020  BY TRANSFER-\rNEFT*HDFC0000240*N167201\r159949...
# 17      15 Jun\r2020  TO TRANSFER-\rUPI/DR/016750898966/Paytm\rDT/PY...
# 18      15 Jun\r2020  TO TRANSFER-\rUPI/DR/016714091214/AGGRE\rPAY/I...
# 19      15 Jun\r2020  BY TRANSFER-\rNEFT*HDFC0000240*N167201\r160499...
# 20      15 Jun\r2020  TO TRANSFER-\rUPI/DR/016715575301/Camde\rn T/H...
# 21      15 Jun\r2020  TO TRANSFER-\rUPI/DR/016720314308/billdesk/\rI...
# 22      16 Jun\r2020  BY TRANSFER-\rNEFT*HDFC0000240*N168201\r161343...
# 23      18 Jun\r2020  TO TRANSFER-\rUPI/DR/017084402011/Paytm\rAi/PY...
# 24      18 Jun\r2020  TO TRANSFER-\rUPI/DR/017084868545/Paytm\rDT/PY...
# 25      19 Jun\r2020  BY TRANSFER-INB\rIMPS017111437268/98260226\r91...
# 26      19 Jun\r2020  TO TRANSFER-\rUPI/DR/017111759472/AVINA\rSH /S...
# 27      23 Jun\r2020  TO TRANSFER-\rUPI/DR/017423945912/billdesk/\rI...
# 28      24 Jun\r2020  TO TRANSFER-\rUPI/DR/017622906332/SHYAM\rMA/HD...
# 29      25 Jun\r2020  BY TRANSFER-\rUPI/CR/017704140037/GOOG\rLEPAY/...
# 30      25 Jun\r2020                                  CREDIT INTEREST--
# 31      30 Jun\r2020  BY TRANSFER-\rNEFT*HDFC0000240*N182201\r172276...
# 32      30 Jun\r2020                              TO TRANSFER-Transfer-
# 33      30 Jun\r2020  ATM WDL-ATM CASH 01821\r+VIRAR EAST           ...
# 34        1 Jul 2020  BY TRANSFER-\rNEFT*HDFC0000240*N183201\r174009...
# 35        1 Jul 2020  TO TRANSFER-INB\rIMPS/P2A/018321520120/XXX\rXX...
# 36        1 Jul 2020  TO TRANSFER-\rUPI/DR/018321308309/ASTHA\rCR/HD...
# 37        2 Jul 2020       DEBIT-CMP MANDATE DEBIT\rBajaj Finance Ltd.-
# 38        2 Jul 2020              DEBIT-CMP MANDATE DEBIT\rEarlySalary-
# 39        3 Jul 2020                              TO TRANSFER-Transfer-
# 40        3 Jul 2020  BY TRANSFER-\rUPI/CR/018521085049/PRATH\rAME/I...
# 41        3 Jul 2020                              BY TRANSFER-Transfer-
# 42        3 Jul 2020  TO TRANSFER-\rUPI/DR/018521101924/Razorp\ray/S...
# 43        4 Jul 2020  BY TRANSFER-\rNEFT*RATN0000999*0001279\r57185*...
# 44        4 Jul 2020                              TO TRANSFER-Transfer-
# 45        5 Jul 2020  BY TRANSFER-\rUPI/CR/018623880304/PRATH\rAME/S...
# 46        5 Jul 2020  TO TRANSFER-\rUPI/DR/018711256867/EURON\rETG/I...
# 47        6 Jul 2020                              TO TRANSFER-Transfer-
# 48        6 Jul 2020        DEBIT-ACHDr\rCITI00002000000037\rBDDMINBFC-
# 49        6 Jul 2020        DEBIT-ACHDr\rCITI00002000000037\rBDDMINBFC-
# 50        6 Jul 2020  BY TRANSFER-\rNEFT*HDFC0000240*N188201\r179284...
# 51        7 Jul 2020  BY TRANSFER-INB\rIMPS018904422636/00000000\r00...
# 52        7 Jul 2020  TO TRANSFER-\rUPI/DR/018914678601/HDFC\rBAN/HD...
# 53        7 Jul 2020  TO TRANSFER-\rUPI/DR/018990401021/Paytm\rMo/PY...
# 54        9 Jul 2020  BY TRANSFER-\rNEFT*HDFC0000240*N191201\r182437...
# 55        9 Jul 2020  TO TRANSFER-\rUPI/DR/019111147373/Billdesk\r/H...
# 56        9 Jul 2020  TO TRANSFER-\rUPI/DR/019116438441/Indiabul\r/U...
# 57       10 Jul 2020  TO TRANSFER-\rUPI/DR/019217554763/Paytm\rMo/PY...
# 58       12 Jul 2020  TO TRANSFER-\rUPI/DR/019413832340/MOBIK\rWIK/H...
# 59       17 Jul 2020  TO TRANSFER-\rUPI/DR/019918150462/MOBIK\rWIK/H...
# 60       17 Jul 2020  TO TRANSFER-\rUPI/DR/019920753756/MOBIK\rWIK/H...
# 61       18 Jul 2020  TO TRANSFER-\rUPI/DR/020021270676/PRATH\rAME/K...
# 62       19 Jul 2020  BY TRANSFER-INB\rIMPS020100137605/90287813\r62...
# 63       19 Jul 2020  BY TRANSFER-INB\rIMPS020120634070/99999999\r88...
# 64       19 Jul 2020  TO TRANSFER-\rUPI/DR/020120989349/ASTHA\rCR/HD...
# 65       21 Jul 2020                 TO TRANSFER-INB Transerv\rPvt Ltd-
# 66       24 Jul 2020  TO TRANSFER-INB\rIMPS/P2A/020613594768/XXX\rXX...
# 67       25 Jul 2020  TO TRANSFER-\rUPI/DR/020720593368/SHYAM\rMA/HD...
# 68       28 Jul 2020  BY TRANSFER-INB\rIMPS021004495604/00000000\r00...
# 69       29 Jul 2020  BY TRANSFER-\rNEFT*HDFC0000240*N211201\r198554...
# 70       29 Jul 2020  TO TRANSFER-\rUPI/DR/021115260322/GAK E\rSO/UT...
# 71       30 Jul 2020                              TO TRANSFER-Transfer-
# 72       31 Jul 2020  BY TRANSFER-INB\rIMPS021318017835/73311543\r59...
# 73       31 Jul 2020                              TO TRANSFER-Transfer-
# 74        1 Aug 2020  ATM WDL-ATM CASH 4381\rNARANFI PHATA         V...
# 75        2 Aug 2020       DEBIT-CMP MANDATE DEBIT\rBajaj Finance Ltd.-
# 76        2 Aug 2020  TO TRANSFER-\rUPI/DR/021520855448/AVINA\rSH /S...
# 77        5 Aug 2020  BY TRANSFER-\rUPI/CR/021800082147/PRATH\rAME/S...
# 78        5 Aug 2020        DEBIT-ACHDr\rCITI00002000000037\rBDDMINBFC-
# 79        5 Aug 2020        DEBIT-ACHDr\rCITI00002000000037\rBDDMINBFC-
# 80              Date
# 81        7 Aug 2020               BY TRANSFER-NEFT*HDFC0000240*N220201
# 85        7 Aug 2020               TO TRANSFER-UPI/DR/022018967363/HDFC
# 89        8 Aug 2020              TO TRANSFER-UPI/DR/022148486936/MahaO
# 92        8 Aug 2020           BY TRANSFER-INBIMPS022121986935/99753880
# 96            11 Aug                             ATM WDL-ATM CASH 02241
# 97              2020                                  NALLASOPARATHANE-
# 99            12 Aug                           TO TRANSFER-INB Transerv
# 100             2020                                           Pvt Ltd-
# 103           13 Aug                                       TO TRANSFER-
# 104             2020   UPI/DR/022617333769/Arihant/UTIB/9960021603/UPI-
# 106           14 Aug                                       TO TRANSFER-
# 107             2020                SBILT14082020111026966343-Transfer-
# 109           14 Aug                                    BY TRANSFER-INB
# 110             2020     IMPS022715014820/9762148373/XX0002/Account va-
# 113           14 Aug                          TO TRANSFER-INB E mandate
# 114             2020                                                  -
# 116           14 Aug                          TO TRANSFER-INB E mandate
# 117             2020                                                  -
# 119           14 Aug                          TO TRANSFER-INB E mandate
# 120             2020                                                  -
# 122           17 Aug                                       BY TRANSFER-
# 123             2020  UPI/CR/023011155291/OMKAR KE/VVSB/omiii31129/UPI-
# 125           17 Aug                                       BY TRANSFER-
# 126             2020            NEFT*HDFC0000240*N230201216729712*ENTOD
# 129           18 Aug                                       BY TRANSFER-
# 130             2020     NEFT*RATN0000999*000133491720*TRANSERV PRIVATE
# 133           18 Aug                                       BY TRANSFER-
# 134             2020     NEFT*RATN0000999*000133492402*TRANSERV PRIVATE
# 137           18 Aug                                       BY TRANSFER-
# 138             2020     NEFT*RATN0000999*000133538595*TRANSERV PRIVATE
# 141           18 Aug                                       BY TRANSFER-
# 142             2020                SBILT18082020183652480891-Transfer-
# 144           19 Aug                                       TO TRANSFER-
# 145             2020  UPI/DR/023212149180/ALOKRAJ/ICIC/ashukla845/Sm...
# 147           20 Aug                                    BY TRANSFER-INB
# 148             2020      IMPS023309247791/9221272552/XX6313/PennyDrop-
# 151     20 Aug\r2020  BY TRANSFER-INB\rIMPS023309534605/97184537\r01...
# 152     20 Aug\r2020  TO TRANSFER-\rSBILT20082020095439689793\r-Tran...
# 153     20 Aug\r2020  TO TRANSFER-\rUPI/DR/023313070043/MOBIK\rWIK/H...
# 154     20 Aug\r2020  BY TRANSFER-\rUPI/CR/023313733568/GOOG\rLEPAY/...
# 155     21 Aug\r2020  TO TRANSFER-\rUPI/DR/023411111469/Camde\rn T/H...
# 156     21 Aug\r2020  TO TRANSFER-\rSBILT21082020162713194593\r-Tran...
# 157     21 Aug\r2020  BY TRANSFER-INB\rIMPS023417002485/97621483\r73...
# 158     21 Aug\r2020  BY TRANSFER-\rNEFT*RATN0000999*0001338\r89441*...
# 159     24 Aug\r2020  TO TRANSFER-\rSBILT24082020105440318087\r-Tran...
# 160     28 Aug\r2020  BY TRANSFER-\rNEFT*HDFC0000240*N241201\r226230...
# 161     28 Aug\r2020  TO TRANSFER-\rUPI/DR/024114521317/BHANI\rX F/K...
# 162     29 Aug\r2020    DEBIT-Mandate fail Chrg txn\rdt.27082020-CASHe-
# 163     29 Aug\r2020  BY TRANSFER-INB\rIMPS024222822073/99999999\r99...
# 164     30 Aug\r2020                              WITHDRAWAL TRANSFER--
# 165     30 Aug\r2020  TO TRANSFER-\rUPI/DR/024321866280/PAYME\r/YESB...
# 166     31 Aug\r2020  DEBIT-CMP MANDATE DEBIT\rHuey Technologies Pri...
# 167     31 Aug\r2020  DEBIT-CMP MANDATE DEBIT\rHuey Technologies Pri...
# 168     31 Aug\r2020  BY TRANSFER-INB\rIMPS024412448232/99999999\r99...
# 169     31 Aug\r2020  TO TRANSFER-\rUPI/DR/024413074361/HDFC\rBAN/HD...
# 170     31 Aug\r2020        TO TRANSFER-INB Motilal\rOswal Financial S-
# 171     31 Aug\r2020  ATM WDL-ATM CASH 7606\rNARANFI PHATA         V...
# 172       1 Sep 2020  TO TRANSFER-\rUPI/DR/024510984622/Kreditb\ree/...
# 173       1 Sep 2020  TO TRANSFER-\rUPI/DR/024515201629/GAK E\rSO/UT...
# 174       2 Sep 2020       DEBIT-CMP MANDATE DEBIT\rBajaj Finance Ltd.-
# 175       2 Sep 2020       DEBIT-CMP MANDATE DEBIT\rBajaj Finance Ltd.-
# 176       2 Sep 2020              DEBIT-CMP MANDATE DEBIT\rEarlySalary-
# 177       3 Sep 2020  BY TRANSFER-INB\rIMPS024710663969/99999999\r99...
# 178       3 Sep 2020  TO TRANSFER-\rUPI/DR/024713088098/NITES\rH M/P...
# 179       3 Sep 2020  BY TRANSFER-\rNEFT*HDFC0000240*N247201\r233150...
# 180       4 Sep 2020  TO TRANSFER-\rUPI/DR/024810321301/SI\rCREVA/ID...
# 181       5 Sep 2020  TO TRANSFER-\rUPI/DR/024910065091/GARAG\rEPR/U...
# 182       5 Sep 2020    DEBIT-Mandate fail Chrg txn\rdt.29042020-CASHe-
# 183       5 Sep 2020        DEBIT-ACHDr\rCITI00002000000037\rBDDMINBFC-
# 184       8 Sep 2020  TO TRANSFER-\rSBILT08092020103710489309\r-Tran...
# 185     11 Sep\r2020  BY TRANSFER-INB\rIMPS025517274336/96197196\r20...
# 186     14 Sep\r2020  BY TRANSFER-\rNEFT*ICIC0000104*CMS1613\r766329...
# 187     15 Sep\r2020                              WITHDRAWAL TRANSFER--
# 188     15 Sep\r2020    DEBIT-Mandate fail Chrg txn\rdt.29052020-CASHe-
# 189     15 Sep\r2020   DEBIT-ACHDr\rNACH00000000006006\rINDIABULLS CON-
# 190     15 Sep\r2020   DEBIT-ACHDr\rNACH00000000006006\rINDIABULLS CON-
# 191     16 Sep\r2020  TO TRANSFER-\rSBILT16092020140348491137\r-Tran...
# 192     23 Sep\r2020  BY TRANSFER-\rNEFT*YESB0000001*N267200\r435507...
# 193     25 Sep\r2020                                  CREDIT INTEREST--
# 194     26 Sep\r2020  BY TRANSFER-\rSBILT26092020104508283827\r-Tran...
# 195     26 Sep\r2020  BY TRANSFER-INB\rIMPS027010326030/90287813\r62...
# 196     26 Sep\r2020  TO TRANSFER-\rSBILT26092020135816803965\r-Tran...
# 197     29 Sep\r2020  BY TRANSFER-INB\rIMPS027320351885/90287813\r62...
# 198     29 Sep\r2020        TO TRANSFER-INB\rTechProcess Payment Servi-
# 199     29 Sep\r2020  BY TRANSFER-INB\rIMPS027320152949/63649001\r06...
# 200     29 Sep\r2020  TO TRANSFER-\rSBILT29092020204244043921\r-Tran...
# 201     30 Sep\r2020  BY TRANSFER-INB\rIMPS027411392663/90287813\r62...
# 202     30 Sep\r2020  TO TRANSFER-\rSBILT30092020115101024433\r-Tran...
# 203     30 Sep\r2020       BULK POSTING-IGAJNALQH0\rTEST AMOUNT REFUND-
# 204     30 Sep\r2020  BY TRANSFER-\rNEFT*HDFC0000240*N274201\r259554...
# 205     30 Sep\r2020  TO TRANSFER-\rSBILT30092020221901404035\r-Tran...
# 206       1 Oct 2020  BY TRANSFER-\rSBILT30092020225427681350\r-Tran...
# 207       1 Oct 2020                              WITHDRAWAL TRANSFER--
# 208       1 Oct 2020       DEBIT-ACHDr\rCITI00002000000037 BD-\rCamden-
# 209       1 Oct 2020  BY TRANSFER-INB\rIMPS027514384100/90287813\r62...
# 210       1 Oct 2020   DEBIT-ACHDr\rNACH00000000004290 TP\rACH INNOFIN-
# 211       1 Oct 2020  TO TRANSFER-\rUPI/DR/027516634587/Kreditb\ree/...
# 212       1 Oct 2020  BY TRANSFER-INB\rIMPS027516373628/90287813\r62...
# 213       1 Oct 2020  TO TRANSFER-\rUPI/DR/027516563238/Whizdm\rI/HD...
#
#         Credit      Debit    Balance
# 0    25,000.00             28,681.79
# 1               20,010.62   8,671.17
# 2         1.00              8,672.17
# 3         2.00              8,674.17
# 4                1,321.00   7,353.17
# 5         1.00              7,354.17
# 6                2,000.00   5,354.17
# 7     3,800.00              9,154.17
# 8                2,925.00   6,229.17
# 9                3,307.00   2,922.17
# 10               2,490.00     432.17
# 11                 350.00      82.17
# 12   14,000.00             14,082.17
# 13              10,000.00   4,082.17
# 14               4,000.00      82.17
# 15                  82.00       0.17
# 16    2,000.00              2,000.17
# 17                 500.00   1,500.17
# 18                 383.54   1,116.63
# 19    4,000.00              5,116.63
# 20               4,506.00     610.63
# 21                 520.42      90.21
# 22    3,000.00              3,090.21
# 23                 379.00   2,711.21
# 24                 471.15   2,240.06
# 25    8,012.03             10,252.09
# 26               5,000.00   5,252.09
# 27                 149.00   5,103.09
# 28               1,000.00   4,103.09
# 29        6.00              4,109.09
# 30       32.00              4,141.09
# 31   40,177.00             44,318.09
# 32              20,000.00  24,318.09
# 33               7,000.00  17,318.09
# 34   11,000.00             28,318.09
# 35               4,500.00  23,818.09
# 36               3,000.00  20,818.09
# 37               1,321.00  19,497.09
# 38               8,281.00  11,216.09
# 39               3,000.00   8,216.09
# 40    1,218.00              9,434.09
# 41      434.00              9,868.09
# 42                  25.00   9,843.09
# 43   14,000.00             23,843.09
# 44              11,750.00  12,093.09
# 45    8,500.00             20,593.09
# 46                 555.00  20,038.09
# 47               7,799.00  12,239.09
# 48               8,863.00   3,376.09
# 49               3,307.00      69.09
# 50    6,174.00              6,243.09
# 51    2,260.86              8,503.95
# 52               3,500.00   5,003.95
# 53                 155.00   4,848.95
# 54   16,799.70             21,648.65
# 55              11,617.20  10,031.45
# 56               2,937.98   7,093.47
# 57                 555.00   6,538.47
# 58                 592.00   5,946.47
# 59                  44.00   5,902.47
# 60                  72.00   5,830.47
# 61                 500.00   5,330.47
# 62      500.00              5,830.47
# 63    4,850.00             10,680.47
# 64               5,000.00   5,680.47
# 65                 581.00   5,099.47
# 66               3,000.00   2,099.47
# 67               1,000.00   1,099.47
# 68    3,375.63              4,475.10
# 69   42,304.00             46,779.10
# 70              16,200.00  30,579.10
# 71              24,000.00   6,579.10
# 72   14,000.00             20,579.10
# 73              12,000.00   8,579.10
# 74               1,500.00   7,079.10
# 75               1,321.00   5,758.10
# 76               5,500.00     258.10
# 77   12,500.00             12,758.10
# 78               3,307.00   9,451.10
# 79               8,863.00     588.10
# 80
# 81    6,174.00              6,762.10
# 85               3,510.00   3,252.10
# 89                  23.60   3,228.50
# 92    3,000.00              6,228.50
# 96               3,500.00   2,728.50
# 97
# 99                 415.00   2,313.50
# 100
# 103                 30.00   2,283.50
# 104
# 106              2,000.00     283.50
# 107
# 109       1.00                284.50
# 110
# 113                 59.00     225.50
# 114
# 116                 59.00     166.50
# 117
# 119                 59.00     107.50
# 120
# 122     220.00                327.50
# 123
# 125   5,034.00              5,361.50
# 126
# 129   1,872.00              7,233.50
# 130
# 133   5,000.00             12,233.50
# 134
# 137   1,655.00             13,888.50
# 138
# 141     200.00             14,088.50
# 142
# 144                500.00  13,588.50
# 145
# 147       1.00             13,589.50
# 148
# 151   4,218.24             17,807.74
# 152             16,000.00   1,807.74
# 153                342.00   1,465.74
# 154       5.00              1,470.74
# 155                500.00     970.74
# 156                800.00     170.74
# 157       1.00                171.74
# 158  15,000.00             15,171.74
# 159             15,170.00       1.74
# 160  50,645.00             50,646.74
# 161             23,500.00  27,146.74
# 162                295.00  26,851.74
# 163       1.00             26,852.74
# 164              7,894.00  18,958.74
# 165              7,350.00  11,608.74
# 166              6,174.00   5,434.74
# 167              1,176.00   4,258.74
# 168  78,105.00             82,363.74
# 169              5,000.00  77,363.74
# 170             30,000.00  47,363.74
# 171              3,500.00  43,863.74
# 172              7,550.00  36,313.74
# 173             16,090.00  20,223.74
# 174              2,811.00  17,412.74
# 175              1,321.00  16,091.74
# 176              9,068.00   7,023.74
# 177   7,350.00             14,373.74
# 178                800.00  13,573.74
# 179  21,552.51             35,126.25
# 180              5,238.00  29,888.25
# 181             19,920.00   9,968.25
# 182                295.00   9,673.25
# 183              3,307.00   6,366.25
# 184              6,366.00       0.25
# 185       1.00                  1.25
# 186  11,793.00             11,794.25
# 187              9,180.00   2,614.25
# 188                295.00   2,319.25
# 189                130.00   2,189.25
# 190                100.00   2,089.25
# 191              2,089.00       0.25
# 192      10.00                 10.25
# 193      46.00                 56.25
# 194     299.00                355.25
# 195     200.00                555.25
# 196                555.00       0.25
# 197      20.00                 20.25
# 198                  1.00      19.25
# 199   5,045.04              5,064.29
# 200              5,060.00       4.29
# 201  20,000.00             20,004.29
# 202             12,000.00   8,004.29
# 203       1.00              8,005.29
# 204   6,793.00             14,798.29
# 205              6,900.00   7,898.29
# 206   5,820.00             13,718.29
# 207              7,894.00   5,824.29
# 208              2,367.00   3,457.29
# 209  15,000.00             18,457.29
# 210              3,438.00  15,019.29
# 211              7,705.00   7,314.29
# 212  13,000.00             20,314.29
# 213              8,863.00  11,451.29
# ('{"Transaction Date":{"0":"1 Jun 2020","1":"1 Jun 2020","2":"1 Jun 2020","3":"1 Jun 2020","4":"2 Jun 2020","5":"2 Jun 2020","6":"4 Jun 2020","7":"4 Jun 2020","8":"5 Jun 2020","9":"5 Jun 2020","10":"5 Jun 2020","11":"6 Jun 2020","12":"8 Jun 2020","13":"8 Jun 2020","14":"8 Jun 2020","15":"9 Jun 2020","16":"15 Jun\\r2020","17":"15 Jun\\r2020","18":"15 Jun\\r2020","19":"15 Jun\\r2020","20":"15 Jun\\r2020","21":"15 Jun\\r2020","22":"16 Jun\\r2020","23":"18 Jun\\r2020","24":"18 Jun\\r2020","25":"19 Jun\\r2020","26":"19 Jun\\r2020","27":"23 Jun\\r2020","28":"24 Jun\\r2020","29":"25 Jun\\r2020","30":"25 Jun\\r2020","31":"30 Jun\\r2020","32":"30 Jun\\r2020","33":"30 Jun\\r2020","34":"1 Jul 2020","35":"1 Jul 2020","36":"1 Jul 2020","37":"2 Jul 2020","38":"2 Jul 2020","39":"3 Jul 2020","40":"3 Jul 2020","41":"3 Jul 2020","42":"3 Jul 2020","43":"4 Jul 2020","44":"4 Jul 2020","45":"5 Jul 2020","46":"5 Jul 2020","47":"6 Jul 2020","48":"6 Jul 2020","49":"6 Jul 2020","50":"6 Jul 2020","51":"7 Jul 2020","52":"7 Jul 2020","53":"7 Jul 2020","54":"9 Jul 2020","55":"9 Jul 2020","56":"9 Jul 2020","57":"10 Jul 2020","58":"12 Jul 2020","59":"17 Jul 2020","60":"17 Jul 2020","61":"18 Jul 2020","62":"19 Jul 2020","63":"19 Jul 2020","64":"19 Jul 2020","65":"21 Jul 2020","66":"24 Jul 2020","67":"25 Jul 2020","68":"28 Jul 2020","69":"29 Jul 2020","70":"29 Jul 2020","71":"30 Jul 2020","72":"31 Jul 2020","73":"31 Jul 2020","74":"1 Aug 2020","75":"2 Aug 2020","76":"2 Aug 2020","77":"5 Aug 2020","78":"5 Aug 2020","79":"5 Aug 2020","80":"Date","81":"7 Aug 2020","85":"7 Aug 2020","89":"8 Aug 2020","92":"8 Aug 2020","96":"11 Aug","97":"2020","99":"12 Aug","100":"2020","103":"13 Aug","104":"2020","106":"14 Aug","107":"2020","109":"14 Aug","110":"2020","113":"14 Aug","114":"2020","116":"14 Aug","117":"2020","119":"14 Aug","120":"2020","122":"17 Aug","123":"2020","125":"17 Aug","126":"2020","129":"18 Aug","130":"2020","133":"18 Aug","134":"2020","137":"18 Aug","138":"2020","141":"18 Aug","142":"2020","144":"19 Aug","145":"2020","147":"20 Aug","148":"2020","151":"20 Aug\\r2020","152":"20 Aug\\r2020","153":"20 Aug\\r2020","154":"20 Aug\\r2020","155":"21 Aug\\r2020","156":"21 Aug\\r2020","157":"21 Aug\\r2020","158":"21 Aug\\r2020","159":"24 Aug\\r2020","160":"28 Aug\\r2020","161":"28 Aug\\r2020","162":"29 Aug\\r2020","163":"29 Aug\\r2020","164":"30 Aug\\r2020","165":"30 Aug\\r2020","166":"31 Aug\\r2020","167":"31 Aug\\r2020","168":"31 Aug\\r2020","169":"31 Aug\\r2020","170":"31 Aug\\r2020","171":"31 Aug\\r2020","172":"1 Sep 2020","173":"1 Sep 2020","174":"2 Sep 2020","175":"2 Sep 2020","176":"2 Sep 2020","177":"3 Sep 2020","178":"3 Sep 2020","179":"3 Sep 2020","180":"4 Sep 2020","181":"5 Sep 2020","182":"5 Sep 2020","183":"5 Sep 2020","184":"8 Sep 2020","185":"11 Sep\\r2020","186":"14 Sep\\r2020","187":"15 Sep\\r2020","188":"15 Sep\\r2020","189":"15 Sep\\r2020","190":"15 Sep\\r2020","191":"16 Sep\\r2020","192":"23 Sep\\r2020","193":"25 Sep\\r2020","194":"26 Sep\\r2020","195":"26 Sep\\r2020","196":"26 Sep\\r2020","197":"29 Sep\\r2020","198":"29 Sep\\r2020","199":"29 Sep\\r2020","200":"29 Sep\\r2020","201":"30 Sep\\r2020","202":"30 Sep\\r2020","203":"30 Sep\\r2020","204":"30 Sep\\r2020","205":"30 Sep\\r2020","206":"1 Oct 2020","207":"1 Oct 2020","208":"1 Oct 2020","209":"1 Oct 2020","210":"1 Oct 2020","211":"1 Oct 2020","212":"1 Oct 2020","213":"1 Oct 2020"},"Narration":{"0":"BY TRANSFER-Transfer to\\rown account-","1":"TO TRANSFER-INB ASTHA\\rCOMMODITIES-","2":"BY TRANSFER-INB\\rIMPS015316697383\\/00000000\\r00\\/XX0040\\/BV5476320-","3":"BY TRANSFER-\\rUPI\\/CR\\/015319322270\\/Razorp\\ray\\/ICIC\\/razorpayx.\\/slice-","4":"DEBIT-CMP MANDATE DEBIT\\rBajaj Finance Ltd.-","5":"BY TRANSFER-INB\\rIMPS015418333478\\/98339440\\r01\\/XX3255\\/Send Money-","6":"TO TRANSFER-Transfer-","7":"BY TRANSFER-\\rUPI\\/CR\\/015615324250\\/PRATH\\rAME\\/INDB\\/9028781362\\/NO RE\\r-","8":"DEBIT-CMP MANDATE DEBIT\\rIVL FINANCE LTD-","9":"DEBIT-ACHDr\\rCITI00002000000037\\rBDDMINBFC-","10 ...
#  '{"Transaction Date":{"3":"1 Jun 2020","7":"4 Jun 2020","11":"6 Jun 2020","13":"8 Jun 2020","14":"8 Jun 2020","17":"15 Jun\\r2020","18":"15 Jun\\r2020","20":"15 Jun\\r2020","21":"15 Jun\\r2020","23":"18 Jun\\r2020","24":"18 Jun\\r2020","26":"19 Jun\\r2020","27":"23 Jun\\r2020","28":"24 Jun\\r2020","29":"25 Jun\\r2020","36":"1 Jul 2020","40":"3 Jul 2020","42":"3 Jul 2020","45":"5 Jul 2020","46":"5 Jul 2020","52":"7 Jul 2020","53":"7 Jul 2020","55":"9 Jul 2020","56":"9 Jul 2020","57":"10 Jul 2020","58":"12 Jul 2020","59":"17 Jul 2020","60":"17 Jul 2020","61":"18 Jul 2020","64":"19 Jul 2020","67":"25 Jul 2020","70":"29 Jul 2020","76":"2 Aug 2020","77":"5 Aug 2020","85":"7 Aug 2020","89":"8 Aug 2020","104":"2020","123":"2020","145":"2020","153":"20 Aug\\r2020","154":"20 Aug\\r2020","155":"21 Aug\\r2020","161":"28 Aug\\r2020","165":"30 Aug\\r2020","169":"31 Aug\\r2020","172":"1 Sep 2020","173":"1 Sep 2020","178":"3 Sep 2020","180":"4 Sep 2020","181":"5 Sep 2020","211":"1 Oct 2020","213":"1 Oct 2020"},"Narration":{"3":"BY TRANSFER-\\rUPI\\/CR\\/015319322270\\/Razorp\\ray\\/ICIC\\/razorpayx.\\/slice-","7":"BY TRANSFER-\\rUPI\\/CR\\/015615324250\\/PRATH\\rAME\\/INDB\\/9028781362\\/NO RE\\r-","11":"TO TRANSFER-\\rUPI\\/DR\\/015813769589\\/Airtel\\rH\\/UTIB\\/airtelin.r\\/Bhart-","13":"TO TRANSFER-\\rUPI\\/DR\\/016022305159\\/ASTHA\\rCR\\/HDFC\\/asthacredi\\/ASTHA-","14":"TO TRANSFER-\\rUPI\\/DR\\/016022308436\\/ASTHA\\rCR\\/HDFC\\/asthatrade\\/ASTHA-","17":"TO TRANSFER-\\rUPI\\/DR\\/016750898966\\/Paytm\\rDT\\/PYTM\\/paydth5848\\/Oid11-","18":"TO TRANSFER-\\rUPI\\/DR\\/016714091214\\/AGGRE\\rPAY\\/ICIC\\/ecom.aggre\\/colle-","20":"TO TRANSFER-\\rUPI\\/DR\\/016715575301\\/Camde\\rn T\\/HDFC\\/zestmoney.\\/ZestM-","21":"TO TRANSFER-\\rUPI\\/DR\\/016720314308\\/billdesk\\/\\rICIC\\/billdesk.a\\/UPI-","23":"TO TRANSFER-\\rUPI\\/DR\\/017084402011\\/Paytm\\rAi\\/PYTM\\/payair7673\\/Oid11-","24":"TO TRANSFER-\\rUPI\\/DR\\/017084868545\\/Paytm\\rDT\\/PYTM\\/paydth5848\\/Oid11-","26":"TO TRANSFER-\\rUPI\\/DR\\/017111759472\\/AVINA\\rSH \\/SBIN\\/avidhavade\\/UPI-","27":"TO TRANSFER-\\rUPI\\/DR\\/017423945912\\/billdesk\\/\\rICIC\\/billdesk.r\\/UPI-","28":"TO TRANSFER-\\rUPI\\/DR\\/017622906332\\/SHYAM\\rMA\\/HDFC\\/shyamchaud\\/Bankn-","29":"BY TRANSFER-\\rUPI\\/CR\\/017704140037\\/GOOG\\rLEPAY\\/UTIB\\/goog-\\rpayme\\/Rewa-","36":"TO TRANSFER-\\rUPI\\/DR\\/018321308309\\/ASTHA\\rCR\\/HDFC\\/asthacredi\\/ASTHA-","40":"BY TRANSFER-\\rUPI\\/CR\\/018521085049\\/PRATH\\rAME\\/INDB\\/9028781362\\/NO RE\\r-","42":"TO TRANSFER-\\rUPI\\/DR\\/018521101924\\/Razorp\\ray\\/SBIN\\/razor.pay@\\/Payvi-","45":"BY TRANSFER-\\rUPI\\/CR\\/018623880304\\/PRATH\\rAME\\/SBIN\\/9028781362\\/NO RE\\r-","46":"TO TRANSFER-\\rUPI\\/DR\\/018711256867\\/EURON\\rETG\\/ICIC\\/euronetgpa\\/UPI-","52":"TO TRANSFER-\\rUPI\\/DR\\/018914678601\\/HDFC\\rBAN\\/HDFC\\/hdfcbank.b\\/HDFCC\\r-","53":"TO TRANSFER-\\rUPI\\/DR\\/018990401021\\/Paytm\\rMo\\/PYTM\\/paybil3066\\/Oid11-","55":"TO TRANSFER-\\rUPI\\/DR\\/019111147373\\/Billdesk\\r\\/HDFC\\/billdeskpa\\/UPI-","56":"TO TRANSFER-\\rUPI\\/DR\\/019116438441\\/Indiabul\\r\\/UTIB\\/indiabulls\\/India-","57":"TO TRANSFER-\\rUPI\\/DR\\/019217554763\\/Paytm\\rMo\\/PYTM\\/paybil3066\\/Oid11-","58":"TO TRANSFER-\\rUPI\\/DR\\/019413832340\\/MOBIK\\rWIK\\/HDFC\\/mobikwikad\\/NA-","59":"TO TRANSFER-\\rUPI\\/DR\\/019918150462\\/MOBIK\\rWIK\\/HDFC\\/mobikwikad\\/NA-","60":"TO TRANSFER-\\rUPI\\/DR\\/019920753756\\/MOBIK\\rWIK\\/HDFC\\/mobikwikad\\/NA-","61":"TO TRANSFER-\\rUPI\\/DR\\/020021270676\\/PRATH\\rAME\\/KKBK\\/9028781362\\/Fund-","64":"TO TRANSFER-\\rUPI\\/DR\\/020120989349\\/ASTHA\\rCR\\/HDFC\\/asthacredi\\/ASTHA-","67":"TO TRANSFER-\\rUPI\\/DR\\/020720593368\\/SHYAM\\rMA\\/HDFC\\/shyamchaud\\/Bankn-","70":"TO TRANSFER-\\rUPI\\/DR\\/021115260322\\/GAK E\\rSO\\/UTIB\\/gakesoluti\\/Quick-","76":"TO TRANSFER-\\rUPI\\/DR\\/021520855448\\/AVINA\\rSH \\/SBIN\\/avidhavade\\/UPI-","77":"BY TRANSFER-\\rUPI\\/CR\\/021800082147\\/PRATH\\rAME\\/ ...
