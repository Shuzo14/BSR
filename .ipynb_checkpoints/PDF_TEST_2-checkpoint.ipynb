# %%
import numpy as np                        # Numerical Python package
import tabula                             # PDF table extra package
import numpy as np
import pandas as pd
import os
import re,string
import operator as op
import sys
import tabula
from dateutil.parser import parse # Fixing the dates
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
def bank_stament_read(file_name,bank_name):
    pdf_file = file_name
    pd.set_option('display.max_rows',None)
    pd.set_option('display.max_columns',None)
    df = tabula.read_pdf(pdf_file, pages = 'all',multiple_tables=True)
    df_list=df
    col_list=["Description","Narration","Remarks","Particulars","DESCRIPTION","Description","Description","PARTICULARS",
                  "Transaction Details","Narration","NARRATION","PERTICULERS","Details of transaction","ransaction Remarks",
                 "Transaction\rParticulars","Transaction Description","ransaction Remarks","Account Description","NARATION",
                 "Narration Chq/Ref No","Deposits","Amount (Rs.)","Credit","CREDIT","Deposit Amt.","DEPOSIT","Deposit",
          "Deposit Amount\r(INR )","Amount","Deposit Amt","Type","Deposit Balance","WithDrawal","Value",
              "Credit (Rs.)","Withdrawal Amt. Deposit Amt.","Deposit Amount\r(INR )","Credit(Rs)","Withdrawals Deposits",
               "Cr Amount","Withdrawal (Dr)/","Withdrawal Amt.","Withdrawal","Withdrawal","DEBIT","Withdrawals","Debit",
          "Withdrawal (Dr)" ,"Withdrawal Amt. Deposit Amt.","Withdrawal (Dr)/","Withdrawal Amount\r(INR )","Debit (Rs.)",
          "Debit(Rs)","WITHDRAWALS","Withdrawal INR","Withdrawal Amt","Amount","Withdrawal Amount","Withdrawals Deposits",
             "Dr Amount", "Balance","Closing Balance","BALANCE","Running Balance","BALANCE","Balance (INR )","Amount","MODE**",
                "Running","Balance(Rs)","Total Amount\rDr/Cr","Date","date","Transaction","Txn","Transaction Date","Debit/Credit",
          "Transaction date", "Txn Date", "Tran Date","Balance (?)","Branch","Cheque No","Chq./Ref.","Entry Date",'Cheque',
             "TRANSACTION\rDATE","Trans Date","Tran Date","DATE","Post Date","Value\rDate","Date (Value\rDate)","Tran Date",
             "Txn dt", "Txn Dt","Value Date" ,'Chq./Ref.No.','Value Dt',"Chq\rNo.","Transaction Description","Total Amount\rDr/Cr",
          "Debit (Rs.)","Credit (Rs.)","Balance (Rs.)","Dr Amount","Cr Amount","Instruments","Total Amou"]

    date_list = ["Date","date","Transaction","Txn","Transaction Date","Transaction date", "Txn Date", "Tran Date","Date",
             "TRANSACTION\rDATE","Trans Date","Tran Date","DATE","Post Date","Value\rDate","Date (Value\rDate)",
             "Txn dt", "Txn Dt","Value Date"]
    narration_list = ["Description","Narration","Remarks","Particulars","DESCRIPTION","Description","Description","PARTICULARS",
                  "Transaction Details","Narration","NARRATION","PERTICULERS","Details of transaction","ransaction Remarks",
                 "Transaction\rParticulars","Transaction Description","ransaction Remarks","Account Description","NARATION",
                 "Narration Chq/Ref No"]

    credit_list = ["Deposits","Amount (Rs.)","Credit","CREDIT","Deposit Amt.","DEPOSIT","Deposit","Deposit Amount\r(INR )","Amount",
              "Credit (Rs.)","Withdrawal Amt. Deposit Amt.","Deposit Amount\r(INR )","Credit(Rs)","Withdrawals Deposits",
               "Cr Amount","Withdrawal (Dr)/","DEPOSITS","WITHDRAWALS"]

    debit_list = ["Withdrawal Amt.","Withdrawal","Withdrawal","DEBIT","Withdrawals","Debit","Withdrawal (Dr)"
              ,"Withdrawal Amt. Deposit Amt.","Withdrawal (Dr)/","Withdrawal Amount\r(INR )","Debit (Rs.)","Debit(Rs)",
             "WITHDRAWALS","Withdrawal INR","Withdrawal Amt","Amount","Withdrawal Amount","Withdrawals Deposits","WithDrawal",
             "Dr Amount"]


    balance_list = ["Balance","Closing Balance","BALANCE","Running Balance","BALANCE","Balance (INR )","Amount",
                "Running","Balance(Rs)","Total Amount\rDr/Cr"]

    test_data=df_list[0]
    col_len=test_data.shape[1]
    tab_cols=test_data.columns
    table_columns=[]
    row_index=[]
    
    for elem in range(len(tab_cols)):
        if tab_cols[elem] in col_list:
            col_name=tab_cols[elem]
            table_columns.append(col_name)
        else:
            table_columns.append("Unknown_column")
    uc_count=op.countOf(table_columns, "Unknown_column")
    
    if uc_count>=3 or len(table_columns)<=3:
        for row_ind in range(col_len-1):
            test_list=list(test_data[tab_cols[row_ind]])
            for i in range(len(col_list)):
                col_el=col_list[i]
                if col_el in test_list:
                    row_inde=test_list.index(col_el)
                    row_index.append(row_inde)
        if len(row_index)==0:
            if len(df_list)<= 4:
                lst_no=0
            else:
                lst_no=4
            data1=df_list[1]
            data2=df_list[2]
            data3=df_list[lst_no]
            data1_columns=[]
            data2_columns=[]
            data3_columns=[]
            page_data1=data1.values.tolist()
            page_data2=data2.values.tolist()
            page_data3=data3.values.tolist()
            data1_cols=data1.columns
            data2_cols=data2.columns
            data3_cols=data3.columns
            for elem in range(len(data1_cols)):
                if data1_cols[elem] in col_list:
                    col_name=data1_cols[elem]
                    data1_columns.append(col_name)
                else:
                    data1_columns.append("Unknown_column")
            for elem in range(len(data2_cols)):
                if data2_cols[elem] in col_list:
                    col_name=data2_cols[elem]
                    data2_columns.append(col_name)
                else:
                    data1_columns.append("Unknown_column")
            for elem in range(len(data3_cols)):
                if data3_cols[elem] in col_list:
                    col_name=data3_cols[elem]
                    data3_columns.append(col_name)
                else:
                    data3_columns.append("Unknown_column")            
            data1_count=op.countOf(data1_columns, "Unknown_column")
            data2_count=op.countOf(data2_columns, "Unknown_column")
            data3_count=op.countOf(data3_columns, "Unknown_column")
            data_uc_count=[data1_count,data2_count,data3_count]
            min_uc_index = data_uc_count.index(min(data_uc_count))
            dict_cols={0:data1_columns,1:data2_columns,2:data3_columns}
            dict_data={0:data1,1:data2,2:data3}
            data_tab_cols=dict_cols[min_uc_index]
            data_first=dict_data[min_uc_index]
            pdf_data=[]
            page_data0=data_first.values.tolist()
            pdf_data=pdf_data + page_data0
            pdf_data=pdf_data + page_data1
            pdf_data=pdf_data + page_data2
            pdf_data=pdf_data + page_data3
            for ls in range(len(df_list)):
                page_data=df[ls].values.tolist()
                pdf_data=pdf_data+page_data
            data1_pdf=pd.DataFrame(pdf_data)
            repete=data1_pdf.shape[1]-len(data_tab_cols)
            for add in range(repete):
                data_tab_cols.append('column_added')
            pdf_data=pd.DataFrame(pdf_data,columns= data_tab_cols)
            data_pdf=pdf_data.replace(np.nan,'')
            com_table=data_pdf
            com_table1=data_pdf
        elif min(row_index)>=2:
            test_data1=test_data.values.tolist()
            row_value=min(row_index)
            data1_col_list=test_data1[row_value]
            data2_col_list=test_data1[row_value+1]
            data_col_list=data1_col_list + data2_col_list
            columns_list=[]
            row_columns=[]
            for elem in range(len(data_col_list)):
                txt=data_col_list[elem]
                txt=str(txt)
                list_txt =list(txt.split())
                columns_list=columns_list+list_txt
            for elem in range(len(columns_list)):
                if columns_list[elem] in col_list:
                    col_name=columns_list[elem]
                    row_columns.append(col_name)
            data1=df_list[1]
            data1=data1.values.tolist()
            #data1=pd.DataFrame(data1,columns=row_columns)
            for lst_len in range(len(df_list)):
                page_data=df_list[lst_len]
                page_data=page_data.values.tolist()
                data1=data1+page_data
            pdf_data1=pd.DataFrame(data1)    
            repete=pdf_data1.shape[1]-len(row_columns)
            for add in range(repete):
                row_columns.append('column_added')
            pdf_data=pd.DataFrame(data1,columns=row_columns)
            pdf_data=pdf_data.replace(np.nan,'')
            com_table=pdf_data
            com_table1=pdf_data
        else:
            num_row=0
            pdf_data=[]
            pdf_data.append(list(df[num_row]))
            pdf_columns=list(df[num_row])
            for ls in range(len(df_list)-num_row):
                page_data=df[ls+num_row].values.tolist()
                pdf_data=pdf_data+page_data
            data_pdf=pd.DataFrame(pdf_data)
            data_pdf=data_pdf.replace(np.nan,'')
            repete=data_pdf.shape[1]-len(pdf_columns)
            for add in range(repete):
                pdf_columns.append('columns')
        
            data_pdf=data_pdf.rename(columns=data_pdf.iloc[0]).drop(data_pdf.index[0]) 
            data_pdf1=data_pdf.rename(columns=data_pdf.iloc[0]).drop(data_pdf.index[0])
            com_table=data_pdf
            com_table1=data_pdf1    
    else:
        num_row=0
        pdf_data=[]
        pdf_data.append(list(df[num_row]))
        pdf_columns=list(df[num_row])
        for ls in range(len(df_list)-num_row):
            page_data=df[ls+num_row].values.tolist()
            pdf_data=pdf_data+page_data
        data_pdf=pd.DataFrame(pdf_data)
        data_pdf=data_pdf.replace(np.nan,'')
        repete=data_pdf.shape[1]-len(pdf_columns)
        for add in range(repete):
            pdf_columns.append('columns')
        
        data_pdf=data_pdf.rename(columns=data_pdf.iloc[0]).drop(data_pdf.index[0]) 
        data_pdf1=data_pdf.rename(columns=data_pdf.iloc[0]).drop(data_pdf.index[0])
        com_table=data_pdf
        com_table1=data_pdf1
    cols = list(com_table.columns)
    cols1 = list(com_table1.columns)
    #cols2 = list(com_table2.columns)
    for i in range(len(cols)):
        if cols[i] in date_list:
            date=cols[i]
            date_ind=i
    for j in range(len(cols1)):
        if cols1[j] in date_list:
            date=cols1[j]
            date_ind=j
    for k in range(len(cols)):
        if cols[k] in narration_list:
            narration=cols[k]
            nar_ind=k
    for l in range(len(cols1)):
        if cols1[l] in narration_list:
            narration=cols1[l]
            nar_ind=l
    for m in range(len(cols)):
        if cols[m] in credit_list:
            credit=cols[m]
            credit_ind=m 
    for n in range(len(cols1)):
        if cols1[n] in credit_list:
            credit=cols1[n]
            credit_ind=n 
    for dbt in range(len(cols)):
        if cols[dbt] in debit_list:
            debit=cols[dbt]
            debit_ind=dbt
    for dbt1 in range(len(cols1)):
        if cols1[dbt1] in debit_list:
            debit=cols1[dbt1]
            debit_ind=dbt1
    for blns in range(len(cols)):
        if cols[blns] in balance_list:
            balance=cols[blns]
            balance_ind=blns
    for blns1 in range(len(cols1)):
        if cols1[blns1] in balance_list:
            balance=cols1[blns1]
            balance_ind=blns1
    Transaction_date =list(com_table[cols[date_ind]])
    Narration = list(com_table[cols[nar_ind]])
    Deposits=list(com_table[cols[credit_ind]])
    Debit = list(com_table[cols[debit_ind]])
    Balance = list(com_table[cols[balance_ind]])
    data4 = pd.DataFrame(Transaction_date,columns=["Transaction Date"])
    data5 = pd.DataFrame(Narration,columns=["Narration"])
    data6 = pd.DataFrame(Deposits,columns=["Credit"])
    data7 = pd.DataFrame(Debit,columns=["Debit"])
    data8 = pd.DataFrame(Balance, columns= ["Balance"])
    data = data4.join(data5)
    data = data.join(data6)
    data = data.join(data7)
    data = data.join(data8)
    data = data.replace(np.nan,'')
    axis_list=["axis-bank","Axis Bank  India","Axis Bank  India","AXIS (UTI) Bank","Axis Bank India","Axis Bank, India",
                   "Axis Ban","Axis Bank","Axis Bank Ltd","Axis Bank Ltd.","Axis Bank ","Axis","axis","AXIS"]

    if bank_name in axis_list:
        for ele in range(len(Narration)-1):
            if Transaction_date[ele] == '' and Balance [ele]== '':
                Narration[ele+1]=str(Narration[ele])+str(Narration[ele+1])
    else:
        for ele in range(len(Narration)):
            if Transaction_date[ele] == '':
                Narration[ele-1]=str(Narration[ele-1])+str(Narration[ele])
    Transaction_date=pd.DataFrame(Transaction_date,columns=["Transaction Date"])
    Narration= pd.DataFrame(Narration,columns=["Narration"])
    Deposits = pd.DataFrame(Deposits,columns=["Credit"])
    Debit = pd.DataFrame(Debit,columns=["Debit"])
    Balance = pd.DataFrame(Balance,columns=["Balance"])
    data=Transaction_date.join(Narration)
    data=data.join(Deposits)
    data=data.join(Debit)
    data=data.join(Balance)
    #data=data.replace('',np.nan)
    #data=data.dropna()
    txn_date = list(data["Transaction Date"])
    cr_list=list(data["Credit"])
    dr_list=list(data["Debit"])
    bls_list=list(data["Balance"])
    row_index=[]
    for row_num in range(len(data["Narration"])):
        if txn_date[row_num]== '':
            a=row_num
            row_index.append(a)
        elif cr_list[row_num]== '' and dr_list[row_num]== '' and bls_list=='' :
            b=row_num
            row_index.append(b)
    unique_row_index = []
    for x in range(len(row_index)):
        if row_index[x] not in unique_row_index:
            row_ind=row_index[x]
            unique_row_index.append(row_ind)
    data=data.drop(unique_row_index,axis=0)
    salary1 = data[data["Narration"].str.contains("SALARY")]
    salary2 = data[data["Narration"].str.contains("Salary")]
    sala_cr= data[data["Narration"].str.contains("CREDIT")]
    salary3 = data[data["Narration"].str.contains("salary")]
    sal_ac = data[data["Narration"].str.contains("SAL")]
    sal_fl = data[data["Narration"].str.contains("Sal")]
    #sal_al = data[data["Narration"].str.contains("sal")]
    NEFT = data[data["Narration"].str.contains("NEFT")]
    IMPS = data[data["Narration"].str.contains("IMPS")]
    sal=sal_ac.append(sal_fl)
    #sal = sal.append(sal_al)
    salary=salary1.append(salary2)
    salary=salary.append(salary3)
    salary=salary.append(sal)
    salary=salary.drop_duplicates(subset="Narration")
    #dataframe.drop_duplicates(subset, keep, inplace, ignore_index)
    UPI = data[data["Narration"].str.contains("UPI")]
    NACH = data[data["Narration"].str.contains("NACH")]
    ACH = data[data["Narration"].str.contains("ACH")]
    NACH=NACH.append(ACH)
    
    return (salary,NEFT,NACH,UPI,IMPS,data)

# %%
bank_name = "hdfc-bank"
file_name= 'C:/Users/VSK/Desktop/Bank_Statement/Bank statement/APP1672079196086829.pdf'

# %%
bank_stament_read(file_name,bank_name)
# Out:
# (Empty DataFrame
#  Columns: [Transaction Date, Narration, Credit, Debit, Balance]
#  Index: [],
#      Transaction Date                                          Narration  \
#  12          04/07/20  NEFT CR-UTIB0002763-SHELLINFOSG GLOBAL DIGITAL...
#  135         05/08/20  NEFT CR-UTIB0002763-SHELLINFOSG GLOBAL DIGITAL...
#  433         07/09/20  NEFT CR-UTIB0002763-SHELLINFOSG GLOBAL DIGITAL...
#
#          Credit Debit    Balance
#  12   65,646.00        65,664.71
#  135  66,049.00        66,113.31
#  433  68,593.00        68,626.29  ,
#  Empty DataFrame
#  Columns: [Transaction Date, Narration, Credit, Debit, Balance]
#  Index: [],
#      Transaction Date                                          Narration  \
#  0           01/07/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667@ICICI...
#  3           02/07/20  UPI-GANDE NAGENDRA-PAY9542592784@PAYTM-PYTM012...
#  6           02/07/20  UPI-KARTHIKEYA BAKERY-Q62052292@YBL-HDFC000104...
#  10          03/07/20  UPI-PAN SHOP-Q53498262@YBL-SBIN0012665-0185385...
#  16          04/07/20        UPI-XXXXXX5709-CITI0000005-018607465490-UPI
#  18          04/07/20        UPI-XXXXXX1123-ICIC0000202-018607472227-UPI
#  20          04/07/20  UPI-KOPPULA HARISH REDDY-KOPPULAHARISHREDDY188...
#  23          04/07/20  UPI-PHONEPECARDPAYMENT-PHONEPECARDPAYMENT@YBL-...
#  26          04/07/20  UPI-PHONEPECARDPAYMENT-PHONEPECARDPAYMENT@YBL-...
#  30          05/07/20  UPI-UPPAIA RAJESH-RAJESH.U557@OKAXIS-UTIB00000...
#  34          05/07/20  UPI-VIVIFI INDIA FINANCE-VIVIFI@KOTAK-KKBK0000...
#  36          05/07/20  UPI-MAHALAXMI KIRANA-Q79174351@YBL-KVBL0001490...
#  38          07/07/20         UPI-XXXXXX0831-PYTM0123456-018980736237-NA
#  40          08/07/20  UPI-BHARATPEMERCHANT-BHARATPE.9100760190@ICICI...
#  43          08/07/20  UPI-MEENAKSHI KIRANA AND-PAYTM-54344645@PAYTM-...
#  46          08/07/20  UPI-MAHALAKSHMI KIRANA A-PAYTM-45988437@PAYTM-...
#  49          08/07/20  UPI-MAHALAXMI KIRANA AND-GPAY-11170637159@OKBI...
#  51          09/07/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  54          09/07/20  UPI-ARBAZ AHMED BASHA MI-ARBAAZAHMED916@OKHDFC...
#  56          09/07/20  UPI-A TARUN KUMAR-TARUN31.TK@OKICICI-DBSS0IN08...
#  58          10/07/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  67          15/07/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  69          15/07/20        UPI-XXXXXX1123-ICIC0000202-019716473680-UPI
#  71          17/07/20  UPI-CHEREDDY RAMESH KUM-RAMESHREDDY918189@OKSB...
#  75          17/07/20  UPI-DONTU SRIKAR-SRIKAR.SHANKAR@OKHDFCBANK-HDF...
#  77          17/07/20  UPI-GANDE NAGENDRA-PAY9542592784@PAYTM-PYTM012...
#  80          17/07/20  UPI-PAYTM MOBILE BILL PA-PAYBIL3066@PAYTM-PYTM...
#  83          18/07/20  UPI-RAMESH MOBILE-Q86958802@YBL-SBIN0005153-02...
#  85          18/07/20  UPI-JAVED PAN SHOP-PAYTM-48071477@PAYTM-PYTM01...
#  88          18/07/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  91          21/07/20           UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM01
#  95          27/07/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  98          29/07/20  UPI-CHERUKURI TAZUDDIN B-TAZUDDINBABA2121-1@OK...
#  101         29/07/20  UPI-PAYTM AIRTEL MOBILE -PAYAIR7673@PAYTM-PYTM...
#  104         30/07/20  UPI-DONTU SRIKAR-SRIKAR.SHANKAR@OKHDFCBANK-HDF...
#  108         31/07/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  111         31/07/20  UPI-CHERUKURI TAZUDDIN -8374207881@YBL-SBIN000...
#  114         31/07/20  UPI-CHEREDDY RAMESH KUM-9493300831@YBL-SBIN000...
#  117         01/08/20  UPI-MANIKANTA TIFFIN-GPAY-11167770224@OKBIZAXI...
#  119         01/08/20  UPI-MANIKANTA TIFFIN-GPAY-11167770225@OKBIZAXI...
#  121         01/08/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  123         01/08/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  126         01/08/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  129         01/08/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  131         01/08/20  UPI-ABHILASH REDDY TUMME-TSREDDY792@OKAXIS-UBI...
#  133         02/08/20  UPI-SIGAR SHOP-Q69311641@YBL-PYTM0123456-02157...
#  138         05/08/20  UPI-CHERUKURI TAZUDDIN B-TAZUDDINBABA2121-1@OK...
#  140         05/08/20  UPI-UPPALA RAJESH-DEEKSHITHAGUNTI@OKAXIS-UTIB0...
#  142         05/08/20  UPI-MY FRIENDS PAN SHOP-PAYTM-46448305@PAYTM-P...
#  145         05/08/20  UPI-CHUNDURI KUMARASWAMY-9640444446@YBL-PYTM01...
#  148         05/08/20  UPI-VIJAYA SANKAR KAMMAR-VJSHNKR42-1@OKAXIS-UT...
#  150         05/08/20  UPI-S S PAN SHOP-PAYTM-31488053@PAYTM-PYTM0123...
#  156         05/08/20        UPI-XXXXXX5709-CITI0000005-021823224576-UPI
#  158         06/08/20        UPI-XXXXXX1123-ICIC0000202-021900227716-UPI
#  163         06/08/20        UPI-XXXXXX1123-ICIC0000202-021900237059-UPI
#  169         06/08/20  UPI-BIBHUTI BISWOL-PAYTM-23663182@PAYTM-PYTM01...
#  172         06/08/20            UPI-BASHIRARAHAMAN-BASHIRARAHAMAN100@OK
#  175         07/08/20  UPI-SANDEEP PAN SHOP-PAYTM-46929767@PAYTM-PYTM...
#  178         07/08/20  UPI-RAYALASEEMA TIFFINS-Q38783647@YBL-ANDB0002...
#  180         07/08/20  UPI-DONTU SRIKAR-SRIKAR.SHANKAR@OKHDFCBANK-HDF...
#  182         07/08/20        UPI-XXXXXX1123-ICIC0000202-022015127771-UPI
#  184         08/08/20           UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM01
#  185         08/08/20            UPI-MOHOMED ATIYABEGUM-ATIYAAKBAR0786@O
#  188         08/08/20  UPI-CHERUKURI TAZUDDIN -TAZUDDINBABA2121@OKHDF...
#  191         09/08/20  UPI-CHERUKURI TAZUDDIN -TAZUDDINBABA2121@OKSBI...
#  193         09/08/20  UPI-A TARUN KUMAR-TARUN31.TK@OKICICI-DBSS0IN08...
#  195         10/08/20  UPI-BHARATPEMERCHANT-BHARATPE.9041242431@ICICI...
#  198         10/08/20            UPI-MRS BHUKYASUGUNAMMA-DAYAKARNAYAK49@
#  202         11/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  205         11/08/20  UPI-SANKAR PHARMACY-Q36940189@YBL-ICIC0001114-...
#  207         12/08/20  UPI-CHEREDDY RAMESH KUM-RAMESHREDDY918189@OKSB...
#  211         12/08/20  UPI-MILAP PAN SHOP-PAY9494440447@PAYTM-PYTM012...
#  214         12/08/20  UPI-CHERUKURI TAZUDDIN -TAZUDDINBABA2121@OKHDF...
#  216         12/08/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  219         12/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  221         12/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  223         12/08/20  UPI-GOOGLEPAY-GOOG-PAYMENT@OKAXIS-UTIB0000553-...
#  225         12/08/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  227         12/08/20  UPI-SANKARARAO PENNIBOYI-SPENNIBO@OKICICI-ICIC...
#  229         13/08/20  UPI-GOOGLEPAY-GOOG-PAYMENT@OKAXIS-UTIB0000553-...
#  231         13/08/20  UPI-SANDEEP PAN SHOP-PAYTM-46929767@PAYTM-PYTM...
#  234         13/08/20  UPI-SANDEEP PAN SHOP-PAYTM-46929767@PAYTM-PYTM...
#  239         13/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  241         13/08/20  UPI-CHERUKURI TAZUDDIN B-TAZUDDINBABA2121-1@OK...
#  243         13/08/20  UPI-SAI TEJASWI CURRYS A-PAYTM-14739674@PAYTM-...
#  246         14/08/20       UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM6310
#  248         15/08/20  UPI-JINKA HARSHA VARDHA-JINKAHARSHAVARDHAN@OKS...
#  250         15/08/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  252         15/08/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  254         15/08/20  UPI-ABHILASH REDDY TUMME-TSREDDY792@OKAXIS-UBI...
#  256         16/08/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  259         16/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  263         17/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  265         17/08/20  UPI-SANDEEP PAN SHOP-PAYTM-46929767@PAYTM-PYTM...
#  268         17/08/20         UPI-XXXXXX0831-PYTM0123456-023064343486-NA
#  270         17/08/20  UPI-SRIKAR DONTHU-SRIKAR.SHANKAR@OKICICI-ICIC0...
#  272         17/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  274         17/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  276         17/08/20  UPI-SHWARMA-PAYTM-34878041@PAYTM-PYTM0123456-0...
#  279         17/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  282         18/08/20  UPI-SANDEEP PAN SHOP-PAYTM-46929767@PAYTM-PYTM...
#  285         18/08/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-ANDB000...
#  293         18/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  296         18/08/20  UPI-KESHABOINA RAVINDER-Q64200876@YBL-ANDB0000...
#  298         19/08/20  UPI-CHALLA VIJYA KUMAR-9640238895@YBL-SBIN0000...
#  301         19/08/20  UPI-CHEREDDY RAMESH KUM-9493300831@YBL-SBIN000...
#  304         19/08/20  UPI-RAJESH KUMAR REDDY B-9502289878@YBL-KARB00...
#  307         19/08/20  UPI-SRIKAR DONTHU-SRIKAR.SHANKAR@OKICICI-ICIC0...
#  309         19/08/20        UPI-XXXXXX1123-ICIC0000202-023217667666-UPI
#  311         19/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  313         20/08/20  UPI-MILAP PAN SHOP-PAY9494440447@PAYTM-PYTM012...
#  316         20/08/20  UPI-D DINESH-9502007962@YBL-KVBL0001490-023354...
#  318         20/08/20  UPI-AL MADINA PAN MAHAL-PAY9533234558@PAYTM-PY...
#  321         21/08/20  UPI-MILAP PAN SHOP-PAY9494440447@PAYTM-PYTM012...
#  324         21/08/20        UPI-XXXXXX1123-ICIC0000202-023413791025-UPI
#  326         21/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  329         22/08/20  UPI-GANDE NAGENDRA-PAY9542592784@PAYTM-PYTM012...
#  332         22/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  335         22/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  338         22/08/20  UPI-KESHABOINA RAVINDER-Q64200876@YBL-ANDB0000...
#  341         24/08/20  UPI-CHERUKURI TAZUDDIN -8374207881@YBL-SBIN000...
#  344         24/08/20  UPI-TANDRA VENKATA RAGHA-SAIKRISHNALADDU77@OKS...
#  346         25/08/20  UPI-CHALLA VIJYA KUMAR-9640238895@YBL-SBIN0000...
#  349         26/08/20  UPI-JINKA HARSHA VARDHA-JINKAHARSHAVARDHAN@OKS...
#  351         26/08/20  UPI-BANNENOLLU SHIVA KUM-SHIVAKUMAR.1999D@OKAX...
#  353         27/08/20  UPI-PAYTM-ADD-MONEY@PAYTM-PYTM0123456-02409621...
#  355         30/08/20  UPI-CHERUKURI TAZUDDIN -TAZUDDINBABA2121@OKHDF...
#  359         30/08/20  UPI-CHERUKURI TAZUDDIN B-TAZUDDINBABA2121-1@OK...
#  362         30/08/20  UPI-CHERUKURI TAZUDDIN B-TAZUDDINBABA2121-1@OK...
#  365         30/08/20  UPI-PAYTM-ADD-MONEY@PAYTM-PYTM0123456-02433969...
#  367         30/08/20  UPI-IMMU PAN SHOP-PAYTM-55826639@PAYTM-PYTM012...
#  370         31/08/20         UPI-MILAP PAN SHOP-PAY9494440447@PAYTM-P10
#  372         01/09/20  UPI-PAYTM-ADD-MONEY@PAYTM-PYTM0123456-02455991...
#  374         01/09/20  UPI-SRINIVAS RAO PERLA-SRNVSPERLA@OKSBI-UCBA00...
#  377         01/09/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667@ICICI...
#  380         01/09/20  UPI-MILAP PAN SHOP-PAY9494440447@PAYTM-PYTM012...
#  383         01/09/20  UPI-KIRANA-PAYTM-52485969@PAYTM-PYTM0123456-02...
#  385         02/09/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667@ICICI...
#  388         02/09/20  UPI-PAYTM AIRTEL RECHARG-PAYAIR7673@PAYTM-PYTM...
#  392         02/09/20            UPI-KONDA ARUNKUMAR-ARUNKENEZEZ-1@OKHDF
#  395         02/09/20  UPI-SAI TEJASWI CURRY PO-GPAY-11166694284@OKBI...
#  397         02/09/20  UPI-IMMU PAN SHOP-PAYTM-55826639@PAYTM-PYTM012...
#  400         03/09/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-ANDB000...
#  402         03/09/20  UPI-K VENKATESWAR RAO-9849168570@YBL-KVBL00014...
#  405         04/09/20  UPI-IMMU PAN SHOP-PAYTM-55826639@PAYTM-PYTM012...
#  408         05/09/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-ANDB000...
#  411         05/09/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667@ICICI...
#  414         05/09/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667@ICICI...
#  417         06/09/20  UPI-JUTURUCHINNA SUDEEP -JUTURCHINNAS@OKAXIS-I...
#  420         06/09/20  UPI-JUTURUCHINNA SUDEEP -JUTURCHINNAS@OKAXIS-I...
#  423         06/09/20  UPI-CHEREDDY RAMESH KUM-RAMESHREDDY918189@OKSB...
#  425         06/09/20  UPI-SNEHA FRESH CHICKEN-PAY9849739194@PAYTM-PY...
#  428         06/09/20  UPI-IMMU PAN SHOP-PAYTM-55826639@PAYTM-PYTM012...
#  431         06/09/20  UPI-PAYTM AIRTEL RECHARG-PAYAIR7673@PAYTM-PYTM...
#  436         07/09/20  UPI-PAYTM AIRTEL RECHARG-PAYAIR7673@PAYTM-PYTM...
#  439         07/09/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-ANDB000...
#  441         07/09/20  UPI-SRINIVAS RAO PERLA-SRINIVAS.PERLA@YBL-HDFC...
#  446         07/09/20  UPI-UPPALA RAJESH-DEEKSHITHAGUNTI@OKAXIS-UTIB0...
#  450         07/09/20  UPI-VIVIFI INDIA FINANCE-VIVIFI@KOTAK-KKBK0000...
#  452         07/09/20  UPI-KOPPULA HARISH REDDY-KOPPULAHARISHREDDY188...
#  455         07/09/20        UPI-XXXXXX1123-ICIC0000202-025112978221-UPI
#  459         07/09/20  UPI-PAYTM RECHARGE OR BI-PAYBIL3066@PAYTM-PYTM...
#  462         07/09/20  UPI-PAYTM-PAYOUT-8725913@PAYTM-PYTM0123456-025...
#  467         08/09/20  UPI-RANDHI PUSHPA-Q57934936@YBL-SBIN0005 00000...
#  469         08/09/20  UPI-PHONEPECARDPAYMENT-PHONEPECARDPAYMEN 00000...
#  472         08/09/20  UPI-ABHILASH REDDY TUMME-9985071930@YBL- 00000...
#  475         08/09/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667 00000...
#  478         09/09/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-A 00000...
#  480         09/09/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIRE 00000...
#  483         09/09/20  UPI-GUNTAKA RAMANA 0000025311389646REDDY-GRAMA...
#  486         11/09/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-A 00000...
#
#          Credit      Debit    Balance
#  0                   36.00     953.00
#  3                   94.00     859.00
#  6                   40.00     819.00
#  10                  12.00      18.71
#  16              18,000.00  46,664.71
#  18               2,000.00  44,664.71
#  20               9,000.00  35,664.71
#  23                 485.00  35,179.71
#  26               1,000.00  34,179.71
#  30               5,700.00   3,479.71
#  34               1,110.90     868.81
#  36                 106.00     762.81
#  38                  50.00     712.81
#  40                  24.00     688.81
#  43                  61.00     627.81
#  46                  52.00     575.81
#  49                  90.00     485.81
#  51      250.00                735.81
#  54    1,000.00              1,735.81
#  56               1,500.00     235.81
#  58                 100.00     135.81
#  67    1,500.00              1,544.01
#  69               1,500.00      44.01
#  71      500.00                544.01
#  75               9,000.00     544.01
#  77                 122.00     422.01
#  80                  71.00     351.01
#  83                  75.00     276.01
#  85                  73.00     203.01
#  88      300.00                503.01
#  91      305.00                308.01
#  95      600.00                600.00
#  98    2,820.00              2,920.00
#  101                 48.00   2,872.00
#  104              1,700.00   1,172.00
#  108                100.00   1,062.31
#  111                200.00     862.31
#  114                200.00     662.31
#  117                 20.00     642.31
#  119                 60.00     582.31
#  121     500.00              1,082.31
#  123   1,000.00              2,082.31
#  126   1,000.00              3,082.31
#  129     500.00              3,582.31
#  131              3,500.00      82.31
#  133                 18.00      64.31
#  138              2,244.00  63,869.31
#  140              5,700.00  58,169.31
#  142                210.00  57,959.31
#  145                 40.00  57,919.31
#  148                210.00  57,709.31
#  150                 98.00  57,611.31
#  156  16,000.00   06/08/20
#  158   2,000.00   06/08/20
#  163   1,200.00   06/08/20
#  169      74.00   06/08/20
#  172     480.00   06/08/20
#  175      36.00   07/08/20
#  178      85.00   07/08/20
#  180   2,000.00   07/08/20
#  182     400.00   07/08/20
#  184              08/08/20      480.0
#  185                 480.0      16.31
#  188   3,182.00              3,198.31
#  191     500.00              3,698.31
#  193                 500.0   3,198.31
#  195                  36.0   3,162.31
#  198     280.00              3,442.31
#  202                  88.0   3,354.31
#  205                  67.0   3,287.31
#  207     500.00              3,787.31
#  211                  54.0   3,734.31
#  214   1,000.00              4,734.31
#  216   2,000.00              6,734.31
#  219                123.00   6,611.31
#  221              1,000.00   5,611.31
#  223       8.00              5,619.31
#  225   1,000.00              6,619.31
#  227              6,500.00     119.31
#  229       8.00                127.31
#  231                 72.00      55.31
#  234                 16.00      39.31
#  239              2,638.00     301.31
#  241                100.00     201.31
#  243                120.00      81.31
#  246                 44.00      37.31
#  248   2,000.00              2,037.31
#  250   1,000.00              3,037.31
#  252     500.00              3,537.31
#  254              3,500.00      37.31
#  256   1,000.00              1,037.31
#  259                950.00      87.31
#  263                122.00   4,965.31
#  265                113.00   4,852.31
#  268                500.00   4,352.31
#  270   8,000.00             12,352.31
#  272              8,000.00   4,352.31
#  274                108.00   4,244.31
#  276                200.00   4,044.31
#  279                 124.0   3,900.31
#  282                  68.0   3,832.31
#  285                 110.0   3,722.31
#  293                 780.0   2,924.61
#  296                  30.0   2,894.61
#  298                 500.0   2,394.61
#  301                  50.0   2,344.61
#  304                 100.0   2,244.61
#  307  10,000.00             12,244.61
#  309   6,744.61   4,000.00
#  311   1,744.61   5,000.00
#  313   1,652.61      92.00
#  316   1,640.61      12.00
#  318   1,586.61      54.00
#  321   1,476.61     110.00
#  324   1,076.61     400.00
#  326     743.61     333.00
#  329     643.61     100.00
#  332     529.61     114.00
#  335     373.61     156.00
#  338     353.61      20.00
#  341                100.00      53.61
#  344      80.00                133.61
#  346                 90.00      43.61
#  349     500.00                543.61
#  351                452.00      91.61
#  353                 91.00       0.61
#  355   1,000.00              1,000.61
#  359     100.00                100.61
#  362     100.00                200.61
#  365                 87.00     113.61
#  367                 58.00      55.61
#  370                  4.00      51.61
#  372                  50.0       1.61
#  374     500.00                501.61
#  377                  57.0     394.29
#  380                  94.0     300.29
#  383                  60.0     240.29
#  385                  18.0     222.29
#  388                  79.0     143.29
#  392   1,000.00              1,011.29
#  395                  95.0     916.29
#  397                  84.0     832.29
#  400                 100.0     732.29
#  402                132.00     480.29
#  405                 65.00     323.29
#  408                125.00     198.29
#  411                 18.00      60.29
#  414                 18.00      42.29
#  417     500.00                542.29
#  420   1,000.00              1,042.29
#  423     400.00                442.29
#  425                387.00      55.29
#  428                 14.00      41.29
#  431                  8.00      33.29
#  436                219.00  68,407.29
#  439                105.00  68,302.29
#  441                500.00  67,802.29
#  446              5,700.00  60,602.29
#  450              1,147.93  40,454.36
#  452              5,000.00  35,454.36
#  455              3,000.00  32,454.36
#  459                599.00   6,855.36
#  462       2.00              6,857.36
#  467                120.00   6,702.26
#  469              2,640.00   4,062.26
#  472              1,000.00   3,062.26
#  475                 50.00   3,012.26
#  478                105.00   2,907.26
#  480                200.00   3,107.26
#  483              3,000.00     107.26
#  486                 75.00      32.26  ,
#      Transaction Date                                          Narration  \
#  29          04/07/20           IMPS-018619341486-NARAYANA REDDY-SBIN-XX
#  32          05/07/20  IMPS-018710378889-SUSHMITHA-KKBK-XXXXXX0874-IN...
#  63          14/07/20  .IMPS P2P 018619341486#04/07/2020 060720-MIR20...
#  65          14/07/20  .IMPS P2P 018710378889#05/07/2020 060720-MIR20...
#  73          17/07/20  IMPS-019914907926-BHOOMIREDDY GARI SHA-HDFC-XX...
#  160         06/08/20  IMPS-021900389303-NARAYANA REDDY-SBIN-XXXXXXX8...
#  165         06/08/20  IMPS-021900389557-SUSHMITHA-KKBK-XXXXXX0874-IN...
#  167         06/08/20  IMPS-021913389040-SRIKAR DONTHU-ICIC-XXXXXXXX2...
#  209         12/08/20  IMPS-022516514328-ANGEL BROKING LIMITE-HDFC-XX...
#  237         13/08/20  IMPS-022613322629-BHOOMIREDDY GARI SHA-HDFC-XX...
#  261         16/08/20  IMPS-022921309812-B BHARATKUMAR REDDY-HDFC-XXX...
#  287         18/08/20  .IMPS P2P 021913389040#06/08/2020 060820-MIR20...
#  289         18/08/20  .IMPS P2P 021900389303#06/08/2020 060820-MIR20...
#  291         18/08/20  .IMPS P2P 021900389557#06/08/2020 060820-MIR20...
#  444         07/09/20   IMPS-025112383844-SUSHMITHA-KKBK-XXXXXX0874-DEBT
#  448         07/09/20  IMPS-025112393058-B SHARATH KUMAR REDDY-CITI-X...
#  457         07/09/20  IMPS-025112309598-NARAYANA REDDY-SBIN-XXXXXXX8...
#
#          Credit      Debit    Balance
#  29              25,000.00   9,179.71
#  32               1,500.00   1,979.71
#  63                   5.90      49.91
#  65                   5.90      44.01
#  73    9,000.00              9,544.01
#  160  25,000.00   06/08/20
#  165   1,500.00   06/08/20
#  167   2,600.00   06/08/20
#  209       1.00              3,788.31
#  237   2,900.00              2,939.31
#  261   5,000.00              5,087.31
#  287                   5.9   3,716.41
#  289                   5.9   3,710.51
#  291                   5.9   3,704.61
#  444              1,500.00  66,302.29
#  448             19,000.00  41,602.29
#  457             25,000.00   7,454.36  ,
#      Transaction Date                                          Narration  \
#  0           01/07/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667@ICICI...
#  3           02/07/20  UPI-GANDE NAGENDRA-PAY9542592784@PAYTM-PYTM012...
#  6           02/07/20  UPI-KARTHIKEYA BAKERY-Q62052292@YBL-HDFC000104...
#  8           02/07/20  DEBIT CARD ANNUAL FEE-JUN-2020 240620-MIR20183...
#  10          03/07/20  UPI-PAN SHOP-Q53498262@YBL-SBIN0012665-0185385...
#  12          04/07/20  NEFT CR-UTIB0002763-SHELLINFOSG GLOBAL DIGITAL...
#  15          04/07/20              IB BILLPAY DR-HDFCTT-524181XXXXXX3919
#  16          04/07/20        UPI-XXXXXX5709-CITI0000005-018607465490-UPI
#  18          04/07/20        UPI-XXXXXX1123-ICIC0000202-018607472227-UPI
#  20          04/07/20  UPI-KOPPULA HARISH REDDY-KOPPULAHARISHREDDY188...
#  23          04/07/20  UPI-PHONEPECARDPAYMENT-PHONEPECARDPAYMENT@YBL-...
#  26          04/07/20  UPI-PHONEPECARDPAYMENT-PHONEPECARDPAYMENT@YBL-...
#  29          04/07/20           IMPS-018619341486-NARAYANA REDDY-SBIN-XX
#  30          05/07/20  UPI-UPPAIA RAJESH-RAJESH.U557@OKAXIS-UTIB00000...
#  32          05/07/20  IMPS-018710378889-SUSHMITHA-KKBK-XXXXXX0874-IN...
#  34          05/07/20  UPI-VIVIFI INDIA FINANCE-VIVIFI@KOTAK-KKBK0000...
#  36          05/07/20  UPI-MAHALAXMI KIRANA-Q79174351@YBL-KVBL0001490...
#  38          07/07/20         UPI-XXXXXX0831-PYTM0123456-018980736237-NA
#  40          08/07/20  UPI-BHARATPEMERCHANT-BHARATPE.9100760190@ICICI...
#  43          08/07/20  UPI-MEENAKSHI KIRANA AND-PAYTM-54344645@PAYTM-...
#  46          08/07/20  UPI-MAHALAKSHMI KIRANA A-PAYTM-45988437@PAYTM-...
#  49          08/07/20  UPI-MAHALAXMI KIRANA AND-GPAY-11170637159@OKBI...
#  51          09/07/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  54          09/07/20  UPI-ARBAZ AHMED BASHA MI-ARBAAZAHMED916@OKHDFC...
#  56          09/07/20  UPI-A TARUN KUMAR-TARUN31.TK@OKICICI-DBSS0IN08...
#  58          10/07/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  63          14/07/20  .IMPS P2P 018619341486#04/07/2020 060720-MIR20...
#  65          14/07/20  .IMPS P2P 018710378889#05/07/2020 060720-MIR20...
#  67          15/07/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  69          15/07/20        UPI-XXXXXX1123-ICIC0000202-019716473680-UPI
#  71          17/07/20  UPI-CHEREDDY RAMESH KUM-RAMESHREDDY918189@OKSB...
#  73          17/07/20  IMPS-019914907926-BHOOMIREDDY GARI SHA-HDFC-XX...
#  75          17/07/20  UPI-DONTU SRIKAR-SRIKAR.SHANKAR@OKHDFCBANK-HDF...
#  77          17/07/20  UPI-GANDE NAGENDRA-PAY9542592784@PAYTM-PYTM012...
#  80          17/07/20  UPI-PAYTM MOBILE BILL PA-PAYBIL3066@PAYTM-PYTM...
#  83          18/07/20  UPI-RAMESH MOBILE-Q86958802@YBL-SBIN0005153-02...
#  85          18/07/20  UPI-JAVED PAN SHOP-PAYTM-48071477@PAYTM-PYTM01...
#  88          18/07/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  90          18/07/20            ATW-512967XXXXXX1202-CHHYD039-HYDERABAD
#  91          21/07/20           UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM01
#  92          21/07/20            EAW-512967XXXXXX1202-00009510-HYDERABAD
#  93          22/07/20  INST-ALERT CHG INC GST APR-JUN2020-MIR20201582...
#  95          27/07/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  97          27/07/20            ATW-512967XXXXXX1202-S1ANHD69-HYDERABAD
#  98          29/07/20  UPI-CHERUKURI TAZUDDIN B-TAZUDDINBABA2121-1@OK...
#  101         29/07/20  UPI-PAYTM AIRTEL MOBILE -PAYAIR7673@PAYTM-PYTM...
#  104         30/07/20  UPI-DONTU SRIKAR-SRIKAR.SHANKAR@OKHDFCBANK-HDF...
#  106         30/07/20  INST-ALERT CHG INC GST APR-JUN2020-MIR20211701...
#  108         31/07/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  111         31/07/20  UPI-CHERUKURI TAZUDDIN -8374207881@YBL-SBIN000...
#  114         31/07/20  UPI-CHEREDDY RAMESH KUM-9493300831@YBL-SBIN000...
#  117         01/08/20  UPI-MANIKANTA TIFFIN-GPAY-11167770224@OKBIZAXI...
#  119         01/08/20  UPI-MANIKANTA TIFFIN-GPAY-11167770225@OKBIZAXI...
#  121         01/08/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  123         01/08/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  126         01/08/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  129         01/08/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  131         01/08/20  UPI-ABHILASH REDDY TUMME-TSREDDY792@OKAXIS-UBI...
#  133         02/08/20  UPI-SIGAR SHOP-Q69311641@YBL-PYTM0123456-02157...
#  135         05/08/20  NEFT CR-UTIB0002763-SHELLINFOSG GLOBAL DIGITAL...
#  138         05/08/20  UPI-CHERUKURI TAZUDDIN B-TAZUDDINBABA2121-1@OK...
#  140         05/08/20  UPI-UPPALA RAJESH-DEEKSHITHAGUNTI@OKAXIS-UTIB0...
#  142         05/08/20  UPI-MY FRIENDS PAN SHOP-PAYTM-46448305@PAYTM-P...
#  145         05/08/20  UPI-CHUNDURI KUMARASWAMY-9640444446@YBL-PYTM01...
#  148         05/08/20  UPI-VIJAYA SANKAR KAMMAR-VJSHNKR42-1@OKAXIS-UT...
#  150         05/08/20  UPI-S S PAN SHOP-PAYTM-31488053@PAYTM-PYTM0123...
#  153         05/08/20  POS 512967XXXXXX1202 QSBIN0000923-021866235679...
#  156         05/08/20        UPI-XXXXXX5709-CITI0000005-021823224576-UPI
#  158         06/08/20        UPI-XXXXXX1123-ICIC0000202-021900227716-UPI
#  160         06/08/20  IMPS-021900389303-NARAYANA REDDY-SBIN-XXXXXXX8...
#  162         06/08/20              IB BILLPAY DR-HDFCTT-524181XXXXXX3919
#  163         06/08/20        UPI-XXXXXX1123-ICIC0000202-021900237059-UPI
#  165         06/08/20  IMPS-021900389557-SUSHMITHA-KKBK-XXXXXX0874-IN...
#  167         06/08/20  IMPS-021913389040-SRIKAR DONTHU-ICIC-XXXXXXXX2...
#  169         06/08/20  UPI-BIBHUTI BISWOL-PAYTM-23663182@PAYTM-PYTM01...
#  172         06/08/20            UPI-BASHIRARAHAMAN-BASHIRARAHAMAN100@OK
#  175         07/08/20  UPI-SANDEEP PAN SHOP-PAYTM-46929767@PAYTM-PYTM...
#  178         07/08/20  UPI-RAYALASEEMA TIFFINS-Q38783647@YBL-ANDB0002...
#  180         07/08/20  UPI-DONTU SRIKAR-SRIKAR.SHANKAR@OKHDFCBANK-HDF...
#  182         07/08/20        UPI-XXXXXX1123-ICIC0000202-022015127771-UPI
#  184         08/08/20           UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM01
#  185         08/08/20            UPI-MOHOMED ATIYABEGUM-ATIYAAKBAR0786@O
#  188         08/08/20  UPI-CHERUKURI TAZUDDIN -TAZUDDINBABA2121@OKHDF...
#  191         09/08/20  UPI-CHERUKURI TAZUDDIN -TAZUDDINBABA2121@OKSBI...
#  193         09/08/20  UPI-A TARUN KUMAR-TARUN31.TK@OKICICI-DBSS0IN08...
#  195         10/08/20  UPI-BHARATPEMERCHANT-BHARATPE.9041242431@ICICI...
#  198         10/08/20            UPI-MRS BHUKYASUGUNAMMA-DAYAKARNAYAK49@
#  202         11/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  205         11/08/20  UPI-SANKAR PHARMACY-Q36940189@YBL-ICIC0001114-...
#  207         12/08/20  UPI-CHEREDDY RAMESH KUM-RAMESHREDDY918189@OKSB...
#  209         12/08/20  IMPS-022516514328-ANGEL BROKING LIMITE-HDFC-XX...
#  211         12/08/20  UPI-MILAP PAN SHOP-PAY9494440447@PAYTM-PYTM012...
#  214         12/08/20  UPI-CHERUKURI TAZUDDIN -TAZUDDINBABA2121@OKHDF...
#  216         12/08/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  219         12/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  221         12/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  223         12/08/20  UPI-GOOGLEPAY-GOOG-PAYMENT@OKAXIS-UTIB0000553-...
#  225         12/08/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  227         12/08/20  UPI-SANKARARAO PENNIBOYI-SPENNIBO@OKICICI-ICIC...
#  229         13/08/20  UPI-GOOGLEPAY-GOOG-PAYMENT@OKAXIS-UTIB0000553-...
#  231         13/08/20  UPI-SANDEEP PAN SHOP-PAYTM-46929767@PAYTM-PYTM...
#  234         13/08/20  UPI-SANDEEP PAN SHOP-PAYTM-46929767@PAYTM-PYTM...
#  237         13/08/20  IMPS-022613322629-BHOOMIREDDY GARI SHA-HDFC-XX...
#  239         13/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  241         13/08/20  UPI-CHERUKURI TAZUDDIN B-TAZUDDINBABA2121-1@OK...
#  243         13/08/20  UPI-SAI TEJASWI CURRYS A-PAYTM-14739674@PAYTM-...
#  246         14/08/20       UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM6310
#  248         15/08/20  UPI-JINKA HARSHA VARDHA-JINKAHARSHAVARDHAN@OKS...
#  250         15/08/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  252         15/08/20  UPI-PAYTM-WALLETMONEYTOBANK@PAYTM-PYTM0123456-...
#  254         15/08/20  UPI-ABHILASH REDDY TUMME-TSREDDY792@OKAXIS-UBI...
#  256         16/08/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIREDDY-1@...
#  259         16/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  261         16/08/20  IMPS-022921309812-B BHARATKUMAR REDDY-HDFC-XXX...
#  263         17/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  265         17/08/20  UPI-SANDEEP PAN SHOP-PAYTM-46929767@PAYTM-PYTM...
#  268         17/08/20         UPI-XXXXXX0831-PYTM0123456-023064343486-NA
#  270         17/08/20  UPI-SRIKAR DONTHU-SRIKAR.SHANKAR@OKICICI-ICIC0...
#  272         17/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  274         17/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  276         17/08/20  UPI-SHWARMA-PAYTM-34878041@PAYTM-PYTM0123456-0...
#  279         17/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  282         18/08/20  UPI-SANDEEP PAN SHOP-PAYTM-46929767@PAYTM-PYTM...
#  285         18/08/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-ANDB000...
#  287         18/08/20  .IMPS P2P 021913389040#06/08/2020 060820-MIR20...
#  289         18/08/20  .IMPS P2P 021900389303#06/08/2020 060820-MIR20...
#  291         18/08/20  .IMPS P2P 021900389557#06/08/2020 060820-MIR20...
#  293         18/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  296         18/08/20  UPI-KESHABOINA RAVINDER-Q64200876@YBL-ANDB0000...
#  298         19/08/20  UPI-CHALLA VIJYA KUMAR-9640238895@YBL-SBIN0000...
#  301         19/08/20  UPI-CHEREDDY RAMESH KUM-9493300831@YBL-SBIN000...
#  304         19/08/20  UPI-RAJESH KUMAR REDDY B-9502289878@YBL-KARB00...
#  307         19/08/20  UPI-SRIKAR DONTHU-SRIKAR.SHANKAR@OKICICI-ICIC0...
#  309         19/08/20        UPI-XXXXXX1123-ICIC0000202-023217667666-UPI
#  311         19/08/20  UPI-ANGEL BROKING LTD-ANGELNSE@HDFCBANK-HDFC00...
#  313         20/08/20  UPI-MILAP PAN SHOP-PAY9494440447@PAYTM-PYTM012...
#  316         20/08/20  UPI-D DINESH-9502007962@YBL-KVBL0001490-023354...
#  318         20/08/20  UPI-AL MADINA PAN MAHAL-PAY9533234558@PAYTM-PY...
#  321         21/08/20  UPI-MILAP PAN SHOP-PAY9494440447@PAYTM-PYTM012...
#  324         21/08/20        UPI-XXXXXX1123-ICIC0000202-023413791025-UPI
#  326         21/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  329         22/08/20  UPI-GANDE NAGENDRA-PAY9542592784@PAYTM-PYTM012...
#  332         22/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  335         22/08/20  UPI-GOLDEN PAN SHOP-PAYTM-45461875@PAYTM-PYTM0...
#  338         22/08/20  UPI-KESHABOINA RAVINDER-Q64200876@YBL-ANDB0000...
#  341         24/08/20  UPI-CHERUKURI TAZUDDIN -8374207881@YBL-SBIN000...
#  344         24/08/20  UPI-TANDRA VENKATA RAGHA-SAIKRISHNALADDU77@OKS...
#  346         25/08/20  UPI-CHALLA VIJYA KUMAR-9640238895@YBL-SBIN0000...
#  349         26/08/20  UPI-JINKA HARSHA VARDHA-JINKAHARSHAVARDHAN@OKS...
#  351         26/08/20  UPI-BANNENOLLU SHIVA KUM-SHIVAKUMAR.1999D@OKAX...
#  353         27/08/20  UPI-PAYTM-ADD-MONEY@PAYTM-PYTM0123456-02409621...
#  355         30/08/20  UPI-CHERUKURI TAZUDDIN -TAZUDDINBABA2121@OKHDF...
#  358         30/08/20            ATW-512967XXXXXX1202-S1ANHD69-HYDERABAD
#  359         30/08/20  UPI-CHERUKURI TAZUDDIN B-TAZUDDINBABA2121-1@OK...
#  362         30/08/20  UPI-CHERUKURI TAZUDDIN B-TAZUDDINBABA2121-1@OK...
#  365         30/08/20  UPI-PAYTM-ADD-MONEY@PAYTM-PYTM0123456-02433969...
#  367         30/08/20  UPI-IMMU PAN SHOP-PAYTM-55826639@PAYTM-PYTM012...
#  370         31/08/20         UPI-MILAP PAN SHOP-PAY9494440447@PAYTM-P10
#  372         01/09/20  UPI-PAYTM-ADD-MONEY@PAYTM-PYTM0123456-02455991...
#  374         01/09/20  UPI-SRINIVAS RAO PERLA-SRNVSPERLA@OKSBI-UCBA00...
#  376         01/09/20                     POS 512967XXXXXX1202 PTM*PAYTM
#  377         01/09/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667@ICICI...
#  380         01/09/20  UPI-MILAP PAN SHOP-PAY9494440447@PAYTM-PYTM012...
#  383         01/09/20  UPI-KIRANA-PAYTM-52485969@PAYTM-PYTM0123456-02...
#  385         02/09/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667@ICICI...
#  388         02/09/20  UPI-PAYTM AIRTEL RECHARG-PAYAIR7673@PAYTM-PYTM...
#  391         02/09/20                     POS 512967XXXXXX1202 PTM*PAYTM
#  392         02/09/20            UPI-KONDA ARUNKUMAR-ARUNKENEZEZ-1@OKHDF
#  395         02/09/20  UPI-SAI TEJASWI CURRY PO-GPAY-11166694284@OKBI...
#  397         02/09/20  UPI-IMMU PAN SHOP-PAYTM-55826639@PAYTM-PYTM012...
#  400         03/09/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-ANDB000...
#  402         03/09/20  UPI-K VENKATESWAR RAO-9849168570@YBL-KVBL00014...
#  404         04/09/20                     POS 512967XXXXXX1202 PTM*PAYTM
#  405         04/09/20  UPI-IMMU PAN SHOP-PAYTM-55826639@PAYTM-PYTM012...
#  408         05/09/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-ANDB000...
#  410         05/09/20              POS 512967XXXXXX1202 IOCL COCO BEGUMP
#  411         05/09/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667@ICICI...
#  414         05/09/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667@ICICI...
#  417         06/09/20  UPI-JUTURUCHINNA SUDEEP -JUTURCHINNAS@OKAXIS-I...
#  419         06/09/20            ATW-512967XXXXXX1202-S1ANHD69-HYDERABAD
#  420         06/09/20  UPI-JUTURUCHINNA SUDEEP -JUTURCHINNAS@OKAXIS-I...
#  422         06/09/20            NWD-512967XXXXXX1202-S1CWI389-HYDERABAD
#  423         06/09/20  UPI-CHEREDDY RAMESH KUM-RAMESHREDDY918189@OKSB...
#  425         06/09/20  UPI-SNEHA FRESH CHICKEN-PAY9849739194@PAYTM-PY...
#  428         06/09/20  UPI-IMMU PAN SHOP-PAYTM-55826639@PAYTM-PYTM012...
#  431         06/09/20  UPI-PAYTM AIRTEL RECHARG-PAYAIR7673@PAYTM-PYTM...
#  433         07/09/20  NEFT CR-UTIB0002763-SHELLINFOSG GLOBAL DIGITAL...
#  436         07/09/20  UPI-PAYTM AIRTEL RECHARG-PAYAIR7673@PAYTM-PYTM...
#  439         07/09/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-ANDB000...
#  441         07/09/20  UPI-SRINIVAS RAO PERLA-SRINIVAS.PERLA@YBL-HDFC...
#  444         07/09/20   IMPS-025112383844-SUSHMITHA-KKBK-XXXXXX0874-DEBT
#  446         07/09/20  UPI-UPPALA RAJESH-DEEKSHITHAGUNTI@OKAXIS-UTIB0...
#  448         07/09/20  IMPS-025112393058-B SHARATH KUMAR REDDY-CITI-X...
#  450         07/09/20  UPI-VIVIFI INDIA FINANCE-VIVIFI@KOTAK-KKBK0000...
#  452         07/09/20  UPI-KOPPULA HARISH REDDY-KOPPULAHARISHREDDY188...
#  455         07/09/20        UPI-XXXXXX1123-ICIC0000202-025112978221-UPI
#  457         07/09/20  IMPS-025112309598-NARAYANA REDDY-SBIN-XXXXXXX8...
#  459         07/09/20  UPI-PAYTM RECHARGE OR BI-PAYBIL3066@PAYTM-PYTM...
#  462         07/09/20  UPI-PAYTM-PAYOUT-8725913@PAYTM-PYTM0123456-025...
#  466         07/09/20  POS REF 512967******1202-09/07 ..IOCL CO 00000...
#  467         08/09/20  UPI-RANDHI PUSHPA-Q57934936@YBL-SBIN0005 00000...
#  469         08/09/20  UPI-PHONEPECARDPAYMENT-PHONEPECARDPAYMEN 00000...
#  472         08/09/20  UPI-ABHILASH REDDY TUMME-9985071930@YBL- 00000...
#  475         08/09/20  UPI-BHARATPEMERCHANT-BHARATPE.9041640667 00000...
#  478         09/09/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-A 00000...
#  480         09/09/20  UPI-BHOOMIREDDY GARI SHA-SHARATHBHOOMIRE 00000...
#  483         09/09/20  UPI-GUNTAKA RAMANA 0000025311389646REDDY-GRAMA...
#  486         11/09/20  UPI-TIKKA VENKATA KALYAN-Q38783647@YBL-A 00000...
#
#          Credit      Debit    Balance
#  0                   36.00     953.00
#  3                   94.00     859.00
#  6                   40.00     819.00
#  8                  788.29      30.71
#  10                  12.00      18.71
#  12   65,646.00             65,664.71
#  15               1,000.00  64,664.71
#  16              18,000.00  46,664.71
#  18               2,000.00  44,664.71
#  20               9,000.00  35,664.71
#  23                 485.00  35,179.71
#  26               1,000.00  34,179.71
#  29              25,000.00   9,179.71
#  30               5,700.00   3,479.71
#  32               1,500.00   1,979.71
#  34               1,110.90     868.81
#  36                 106.00     762.81
#  38                  50.00     712.81
#  40                  24.00     688.81
#  43                  61.00     627.81
#  46                  52.00     575.81
#  49                  90.00     485.81
#  51      250.00                735.81
#  54    1,000.00              1,735.81
#  56               1,500.00     235.81
#  58                 100.00     135.81
#  63                   5.90      49.91
#  65                   5.90      44.01
#  67    1,500.00              1,544.01
#  69               1,500.00      44.01
#  71      500.00                544.01
#  73    9,000.00              9,544.01
#  75               9,000.00     544.01
#  77                 122.00     422.01
#  80                  71.00     351.01
#  83                  75.00     276.01
#  85                  73.00     203.01
#  88      300.00                503.01
#  90                 500.00       3.01
#  91      305.00                308.01
#  92                 300.00       8.01
#  93                   8.01       0.00
#  95      600.00                600.00
#  97                 500.00     100.00
#  98    2,820.00              2,920.00
#  101                 48.00   2,872.00
#  104              1,700.00   1,172.00
#  106                  9.69   1,162.31
#  108                100.00   1,062.31
#  111                200.00     862.31
#  114                200.00     662.31
#  117                 20.00     642.31
#  119                 60.00     582.31
#  121     500.00              1,082.31
#  123   1,000.00              2,082.31
#  126   1,000.00              3,082.31
#  129     500.00              3,582.31
#  131              3,500.00      82.31
#  133                 18.00      64.31
#  135  66,049.00             66,113.31
#  138              2,244.00  63,869.31
#  140              5,700.00  58,169.31
#  142                210.00  57,959.31
#  145                 40.00  57,919.31
#  148                210.00  57,709.31
#  150                 98.00  57,611.31
#  153              2,720.00  54,891.31
#  156  16,000.00   06/08/20
#  158   2,000.00   06/08/20
#  160  25,000.00   06/08/20
#  162   3,000.00   06/08/20
#  163   1,200.00   06/08/20
#  165   1,500.00   06/08/20
#  167   2,600.00   06/08/20
#  169      74.00   06/08/20
#  172     480.00   06/08/20
#  175      36.00   07/08/20
#  178      85.00   07/08/20
#  180   2,000.00   07/08/20
#  182     400.00   07/08/20
#  184              08/08/20      480.0
#  185                 480.0      16.31
#  188   3,182.00              3,198.31
#  191     500.00              3,698.31
#  193                 500.0   3,198.31
#  195                  36.0   3,162.31
#  198     280.00              3,442.31
#  202                  88.0   3,354.31
#  205                  67.0   3,287.31
#  207     500.00              3,787.31
#  209       1.00              3,788.31
#  211                  54.0   3,734.31
#  214   1,000.00              4,734.31
#  216   2,000.00              6,734.31
#  219                123.00   6,611.31
#  221              1,000.00   5,611.31
#  223       8.00              5,619.31
#  225   1,000.00              6,619.31
#  227              6,500.00     119.31
#  229       8.00                127.31
#  231                 72.00      55.31
#  234                 16.00      39.31
#  237   2,900.00              2,939.31
#  239              2,638.00     301.31
#  241                100.00     201.31
#  243                120.00      81.31
#  246                 44.00      37.31
#  248   2,000.00              2,037.31
#  250   1,000.00              3,037.31
#  252     500.00              3,537.31
#  254              3,500.00      37.31
#  256   1,000.00              1,037.31
#  259                950.00      87.31
#  261   5,000.00              5,087.31
#  263                122.00   4,965.31
#  265                113.00   4,852.31
#  268                500.00   4,352.31
#  270   8,000.00             12,352.31
#  272              8,000.00   4,352.31
#  274                108.00   4,244.31
#  276                200.00   4,044.31
#  279                 124.0   3,900.31
#  282                  68.0   3,832.31
#  285                 110.0   3,722.31
#  287                   5.9   3,716.41
#  289                   5.9   3,710.51
#  291                   5.9   3,704.61
#  293                 780.0   2,924.61
#  296                  30.0   2,894.61
#  298                 500.0   2,394.61
#  301                  50.0   2,344.61
#  304                 100.0   2,244.61
#  307  10,000.00             12,244.61
#  309   6,744.61   4,000.00
#  311   1,744.61   5,000.00
#  313   1,652.61      92.00
#  316   1,640.61      12.00
#  318   1,586.61      54.00
#  321   1,476.61     110.00
#  324   1,076.61     400.00
#  326     743.61     333.00
#  329     643.61     100.00
#  332     529.61     114.00
#  335     373.61     156.00
#  338     353.61      20.00
#  341                100.00      53.61
#  344      80.00                133.61
#  346                 90.00      43.61
#  349     500.00                543.61
#  351                452.00      91.61
#  353                 91.00       0.61
#  355   1,000.00              1,000.61
#  358              1,000.00       0.61
#  359     100.00                100.61
#  362     100.00                200.61
#  365                 87.00     113.61
#  367                 58.00      55.61
#  370                  4.00      51.61
#  372                  50.0       1.61
#  374     500.00                501.61
#  376                 50.32     451.29
#  377                  57.0     394.29
#  380                  94.0     300.29
#  383                  60.0     240.29
#  385                  18.0     222.29
#  388                  79.0     143.29
#  391                 132.0      11.29
#  392   1,000.00              1,011.29
#  395                  95.0     916.29
#  397                  84.0     832.29
#  400                 100.0     732.29
#  402                132.00     480.29
#  404                 92.00     388.29
#  405                 65.00     323.29
#  408                125.00     198.29
#  410                120.00      78.29
#  411                 18.00      60.29
#  414                 18.00      42.29
#  417     500.00                542.29
#  419                500.00      42.29
#  420   1,000.00              1,042.29
#  422              1,000.00      42.29
#  423     400.00                442.29
#  425                387.00      55.29
#  428                 14.00      41.29
#  431                  8.00      33.29
#  433  68,593.00             68,626.29
#  436                219.00  68,407.29
#  439                105.00  68,302.29
#  441                500.00  67,802.29
#  444              1,500.00  66,302.29
#  446              5,700.00  60,602.29
#  448             19,000.00  41,602.29
#  450              1,147.93  40,454.36
#  452              5,000.00  35,454.36
#  455              3,000.00  32,454.36
#  457             25,000.00   7,454.36
#  459                599.00   6,855.36
#  462       2.00              6,857.36
#  466                  0.90   6,822.26
#  467                120.00   6,702.26
#  469              2,640.00   4,062.26
#  472              1,000.00   3,062.26
#  475                 50.00   3,012.26
#  478                105.00   2,907.26
#  480                200.00   3,107.26
#  483              3,000.00     107.26
#  486                 75.00      32.26  )
